# %%
# Path en la web api:
# Asset Server/Databases/PIWebServices-Elements/Bombas-Elements/9300V-Elements/TAGBOMBA-Value
import warnings
warnings.simplefilter("ignore", category=UserWarning)
import grequests, json
from requests.auth import HTTPBasicAuth
import pandas as pd
import time
import datetime

# %%
now = datetime.datetime.now()
nombre_archivo = '9300V_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
datos_PI_9300PP60 = pd.DataFrame(columns=[])
datos_PI_9300PP61 = pd.DataFrame(columns=[])
datos_PI_9300PP62 = pd.DataFrame(columns=[])
datos_PI_9300PP63 = pd.DataFrame(columns=[])
datos_PI_9300PP64 = pd.DataFrame(columns=[])
with pd.ExcelWriter('~/jupyter/Datos_Bombas/9300V/'+nombre_archivo) as writer:  
    datos_PI_9300PP60.to_excel(writer,sheet_name='PP-060')
    datos_PI_9300PP61.to_excel(writer,sheet_name='PP-061')
    datos_PI_9300PP62.to_excel(writer,sheet_name='PP-062')
    datos_PI_9300PP63.to_excel(writer,sheet_name='PP-063')
    datos_PI_9300PP64.to_excel(writer,sheet_name='PP-064')
    
#####
nombre_archivo = '9400V_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
datos_PI_9400PP11 = pd.DataFrame(columns=[])
datos_PI_9400PP12 = pd.DataFrame(columns=[])
datos_PI_9400PP13 = pd.DataFrame(columns=[])
datos_PI_9400PP14 = pd.DataFrame(columns=[])
datos_PI_9400PP15 = pd.DataFrame(columns=[])
datos_PI_9400PP16 = pd.DataFrame(columns=[])
with pd.ExcelWriter('~/jupyter/Datos_Bombas/9400V/'+nombre_archivo) as writer:  
    datos_PI_9400PP11.to_excel(writer,sheet_name='PP-011')
    datos_PI_9400PP12.to_excel(writer,sheet_name='PP-012')
    datos_PI_9400PP13.to_excel(writer,sheet_name='PP-013')
    datos_PI_9400PP14.to_excel(writer,sheet_name='PP-014')
    datos_PI_9400PP15.to_excel(writer,sheet_name='PP-015')
    datos_PI_9400PP16.to_excel(writer,sheet_name='PP-016')
    
#####    
nombre_archivo = '6650H_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
datos_PI_6650PP1 = pd.DataFrame(columns=[])
datos_PI_6650PP2 = pd.DataFrame(columns=[])
datos_PI_6650PP3 = pd.DataFrame(columns=[])
datos_PI_6650PP4 = pd.DataFrame(columns=[])
datos_PI_6650PP5 = pd.DataFrame(columns=[])
datos_PI_6650PP6 = pd.DataFrame(columns=[])
with pd.ExcelWriter('~/jupyter/Datos_Bombas/6650H/'+nombre_archivo) as writer:  
    datos_PI_6650PP1.to_excel(writer,sheet_name='PP-001')
    datos_PI_6650PP2.to_excel(writer,sheet_name='PP-002')
    datos_PI_6650PP3.to_excel(writer,sheet_name='PP-003')
    datos_PI_6650PP4.to_excel(writer,sheet_name='PP-004')
    datos_PI_6650PP5.to_excel(writer,sheet_name='PP-005')
    datos_PI_6650PP6.to_excel(writer,sheet_name='PP-006')
    
#####    
nombre_archivo = '6650V_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
datos_PI_6650PP13 = pd.DataFrame(columns=[])
datos_PI_6650PP14 = pd.DataFrame(columns=[])
datos_PI_6650PP15 = pd.DataFrame(columns=[])
datos_PI_6650PP16 = pd.DataFrame(columns=[])
datos_PI_6650PP17 = pd.DataFrame(columns=[])
datos_PI_6650PP18 = pd.DataFrame(columns=[])
datos_PI_6650PP19 = pd.DataFrame(columns=[])
datos_PI_6650PP20 = pd.DataFrame(columns=[])
datos_PI_6650PP21 = pd.DataFrame(columns=[])
datos_PI_6650PP22 = pd.DataFrame(columns=[])
datos_PI_6650PP23 = pd.DataFrame(columns=[])
datos_PI_6650PP24 = pd.DataFrame(columns=[])
with pd.ExcelWriter('~/jupyter/Datos_Bombas/6650V/'+nombre_archivo) as writer:  
    datos_PI_6650PP13.to_excel(writer,sheet_name='PP-013')
    datos_PI_6650PP14.to_excel(writer,sheet_name='PP-014')
    datos_PI_6650PP15.to_excel(writer,sheet_name='PP-015')
    datos_PI_6650PP16.to_excel(writer,sheet_name='PP-016')
    datos_PI_6650PP17.to_excel(writer,sheet_name='PP-017')
    datos_PI_6650PP18.to_excel(writer,sheet_name='PP-018')
    datos_PI_6650PP19.to_excel(writer,sheet_name='PP-019')
    datos_PI_6650PP20.to_excel(writer,sheet_name='PP-020')
    datos_PI_6650PP21.to_excel(writer,sheet_name='PP-021')
    datos_PI_6650PP22.to_excel(writer,sheet_name='PP-022')
    datos_PI_6650PP23.to_excel(writer,sheet_name='PP-023')
    datos_PI_6650PP24.to_excel(writer,sheet_name='PP-024')
    
#####
nombre_archivo = '6750H_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
datos_PI_6750PP9 = pd.DataFrame(columns=[])
datos_PI_6750PP10 = pd.DataFrame(columns=[])
datos_PI_6750PP11 = pd.DataFrame(columns=[])
with pd.ExcelWriter('~/jupyter/Datos_Bombas/6750H/'+nombre_archivo) as writer:  
    datos_PI_6750PP9.to_excel(writer,sheet_name='PP-009')
    datos_PI_6750PP10.to_excel(writer,sheet_name='PP-010')
    datos_PI_6750PP11.to_excel(writer,sheet_name='PP-011')
    
#####
nombre_archivo = '6750V_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
datos_PI_6750PP1 = pd.DataFrame(columns=[])
datos_PI_6750PP2 = pd.DataFrame(columns=[])
datos_PI_6750PP3 = pd.DataFrame(columns=[])
datos_PI_6750PP4 = pd.DataFrame(columns=[])
with pd.ExcelWriter('~/jupyter/Datos_Bombas/6750V/'+nombre_archivo) as writer:  
    datos_PI_6750PP1.to_excel(writer,sheet_name='PP-001')
    datos_PI_6750PP2.to_excel(writer,sheet_name='PP-002')
    datos_PI_6750PP3.to_excel(writer,sheet_name='PP-003')
    datos_PI_6750PP4.to_excel(writer,sheet_name='PP-004')
    
#####
nombre_archivo = '9300_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
datos_PI_9300PP20 = pd.DataFrame(columns=[])
datos_PI_9300PP21 = pd.DataFrame(columns=[])
datos_PI_9300PP22 = pd.DataFrame(columns=[])
with pd.ExcelWriter('~/jupyter/Datos_Bombas/EB1/'+nombre_archivo) as writer:  
    datos_PI_9300PP20.to_excel(writer,sheet_name='PP-020')
    datos_PI_9300PP21.to_excel(writer,sheet_name='PP-021')
    datos_PI_9300PP22.to_excel(writer,sheet_name='PP-022')
    
######
nombre_archivo = '9300_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
datos_PI_9300PP25 = pd.DataFrame(columns=[])
datos_PI_9300PP26 = pd.DataFrame(columns=[])
datos_PI_9300PP27 = pd.DataFrame(columns=[])
datos_PI_9300PP28 = pd.DataFrame(columns=[])
datos_PI_9300PP29 = pd.DataFrame(columns=[])
with pd.ExcelWriter('~/jupyter/Datos_Bombas/EB2/'+nombre_archivo) as writer:  
    datos_PI_9300PP25.to_excel(writer,sheet_name='PP-025')
    datos_PI_9300PP26.to_excel(writer,sheet_name='PP-026')
    datos_PI_9300PP27.to_excel(writer,sheet_name='PP-027')
    datos_PI_9300PP28.to_excel(writer,sheet_name='PP-028')
    datos_PI_9300PP29.to_excel(writer,sheet_name='PP-029')
    
#####
nombre_archivo = '9300_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
datos_PI_9300PP31 = pd.DataFrame(columns=[])
datos_PI_9300PP32 = pd.DataFrame(columns=[])
datos_PI_9300PP33 = pd.DataFrame(columns=[])
datos_PI_9300PP34 = pd.DataFrame(columns=[])
datos_PI_9300PP35 = pd.DataFrame(columns=[])
with pd.ExcelWriter('~/jupyter/Datos_Bombas/EB3/'+nombre_archivo) as writer:  
    datos_PI_9300PP31.to_excel(writer,sheet_name='PP-031')
    datos_PI_9300PP32.to_excel(writer,sheet_name='PP-032')
    datos_PI_9300PP33.to_excel(writer,sheet_name='PP-033')
    datos_PI_9300PP34.to_excel(writer,sheet_name='PP-034')
    datos_PI_9300PP35.to_excel(writer,sheet_name='PP-035')
    
#####
nombre_archivo = '9300_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
datos_PI_9300PP65 = pd.DataFrame(columns=[])
datos_PI_9300PP66 = pd.DataFrame(columns=[])
datos_PI_9300PP67 = pd.DataFrame(columns=[])
datos_PI_9300PP68 = pd.DataFrame(columns=[])
datos_PI_9300PP69 = pd.DataFrame(columns=[])
with pd.ExcelWriter('~/jupyter/Datos_Bombas/EB5/'+nombre_archivo) as writer:  
    datos_PI_9300PP65.to_excel(writer,sheet_name='PP-065')
    datos_PI_9300PP66.to_excel(writer,sheet_name='PP-066')
    datos_PI_9300PP67.to_excel(writer,sheet_name='PP-067')
    datos_PI_9300PP68.to_excel(writer,sheet_name='PP-068')
    datos_PI_9300PP69.to_excel(writer,sheet_name='PP-069')
    
#####    
nombre_archivo = '9300_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
datos_PI_9300PP71 = pd.DataFrame(columns=[])
datos_PI_9300PP72 = pd.DataFrame(columns=[])
datos_PI_9300PP73 = pd.DataFrame(columns=[])
datos_PI_9300PP74 = pd.DataFrame(columns=[])
datos_PI_9300PP75 = pd.DataFrame(columns=[])
with pd.ExcelWriter('~/jupyter/Datos_Bombas/EB6/'+nombre_archivo) as writer:  
    datos_PI_9300PP71.to_excel(writer,sheet_name='PP-071')
    datos_PI_9300PP72.to_excel(writer,sheet_name='PP-072')
    datos_PI_9300PP73.to_excel(writer,sheet_name='PP-073')
    datos_PI_9300PP74.to_excel(writer,sheet_name='PP-074')
    datos_PI_9300PP75.to_excel(writer,sheet_name='PP-075')

# %%
while True:
    ######### 9300V ##########
    reqs = [grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwaZsmuFyz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w5MzAwVlw5MzAwLVBQLTA2MA/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwiIjb0lyz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w5MzAwVlw5MzAwLVBQLTA2MQ/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwi4jb0lyz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w5MzAwVlw5MzAwLVBQLTA2Mg/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwQELL3lyz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w5MzAwVlw5MzAwLVBQLTA2Mw/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwQ0LL3lyz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w5MzAwVlw5MzAwLVBQLTA2NA/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),]
    valores = grequests.map(reqs)
    
    time_stamp = json.loads(valores[0].text)['Items'][0]['Value']['Timestamp']
    pres_est4 = json.loads(valores[0].text)['Items'][0]['Value']['Value']
    flow = json.loads(valores[0].text)['Items'][1]['Value']['Value']
    temp_devC2 = json.loads(valores[0].text)['Items'][2]['Value']['Value']
    temp_devC1 = json.loads(valores[0].text)['Items'][3]['Value']['Value']
    temp_devB2 = json.loads(valores[0].text)['Items'][4]['Value']['Value']
    temp_devB1 = json.loads(valores[0].text)['Items'][5]['Value']['Value']
    temp_devA2 = json.loads(valores[0].text)['Items'][6]['Value']['Value']
    temp_devA1 = json.loads(valores[0].text)['Items'][7]['Value']['Value']
    temp_descB = json.loads(valores[0].text)['Items'][8]['Value']['Value']
    temp_descA = json.loads(valores[0].text)['Items'][9]['Value']['Value']
    pump_run = json.loads(valores[0].text)['Items'][10]['Value']['Value']
    pot_act = json.loads(valores[0].text)['Items'][11]['Value']['Value']
    hor_total = json.loads(valores[0].text)['Items'][12]['Value']['Value']
    hor_op = json.loads(valores[0].text)['Items'][13]['Value']['Value']
    estado = json.loads(valores[0].text)['Items'][14]['Value']['Value']
    ef_inst = json.loads(valores[0].text)['Items'][15]['Value']['Value']
    corr_C = json.loads(valores[0].text)['Items'][16]['Value']['Value']
    corr_B = json.loads(valores[0].text)['Items'][17]['Value']['Value']
    corr_A = json.loads(valores[0].text)['Items'][18]['Value']['Value']
    datos_actual_9300PP60 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_run],'Estado bomba':[estado],'Horometro total':[hor_total],
                                 'Horas operando':[hor_op],'Presion Estacion 4':[pres_est4],'Flujo':[flow],'Temperatura devanado A1':[temp_devA1],
                                 'Temperatura devanado A2':[temp_devA2],'Temperatura devanado B1':[temp_devB1], 'Temperatura devanado B2':[temp_devB2],
                                 'Temperatura devanado C1':[temp_devC1], 'Temperatura devanado C2':[temp_devC2], 'Temperatura descanso A':[temp_descA],
                                 'Temperatura descanso B':[temp_descB],'Potencia Activa':[pot_act],'Eficiencia instantanea':[ef_inst],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP60 = datos_PI_9300PP60.append(datos_actual_9300PP60,ignore_index=True)
    
    ##########
    time_stamp = json.loads(valores[1].text)['Items'][0]['Value']['Timestamp']
    pres_est4 = json.loads(valores[1].text)['Items'][0]['Value']['Value']
    flow = json.loads(valores[1].text)['Items'][1]['Value']['Value']
    temp_devC2 = json.loads(valores[1].text)['Items'][2]['Value']['Value']
    temp_devC1 = json.loads(valores[1].text)['Items'][3]['Value']['Value']
    temp_devB2 = json.loads(valores[1].text)['Items'][4]['Value']['Value']
    temp_devB1 = json.loads(valores[1].text)['Items'][5]['Value']['Value']
    temp_devA2 = json.loads(valores[1].text)['Items'][6]['Value']['Value']
    temp_devA1 = json.loads(valores[1].text)['Items'][7]['Value']['Value']
    temp_descB = json.loads(valores[1].text)['Items'][8]['Value']['Value']
    temp_descA = json.loads(valores[1].text)['Items'][9]['Value']['Value']
    pump_run = json.loads(valores[1].text)['Items'][10]['Value']['Value']
    pot_act = json.loads(valores[1].text)['Items'][11]['Value']['Value']
    hor_total = json.loads(valores[1].text)['Items'][12]['Value']['Value']
    hor_op = json.loads(valores[1].text)['Items'][13]['Value']['Value']
    estado = json.loads(valores[1].text)['Items'][14]['Value']['Value']
    ef_inst = json.loads(valores[1].text)['Items'][15]['Value']['Value']
    corr_C = json.loads(valores[1].text)['Items'][16]['Value']['Value']
    corr_B = json.loads(valores[1].text)['Items'][17]['Value']['Value']
    corr_A = json.loads(valores[1].text)['Items'][18]['Value']['Value']
    datos_actual_9300PP61 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_run],'Estado bomba':[estado],'Horometro total':[hor_total],
                                 'Horas operando':[hor_op],'Presion Estacion 4':[pres_est4],'Flujo':[flow],'Temperatura devanado A1':[temp_devA1],
                                 'Temperatura devanado A2':[temp_devA2],'Temperatura devanado B1':[temp_devB1], 'Temperatura devanado B2':[temp_devB2],
                                 'Temperatura devanado C1':[temp_devC1], 'Temperatura devanado C2':[temp_devC2], 'Temperatura descanso A':[temp_descA],
                                 'Temperatura descanso B':[temp_descB],'Potencia Activa':[pot_act],'Eficiencia instantanea':[ef_inst],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP61 = datos_PI_9300PP61.append(datos_actual_9300PP61,ignore_index=True)
    
    #########
    time_stamp = json.loads(valores[2].text)['Items'][0]['Value']['Timestamp']
    pres_est4 = json.loads(valores[2].text)['Items'][0]['Value']['Value']
    flow = json.loads(valores[2].text)['Items'][1]['Value']['Value']
    temp_devC2 = json.loads(valores[2].text)['Items'][2]['Value']['Value']
    temp_devC1 = json.loads(valores[2].text)['Items'][3]['Value']['Value']
    temp_devB2 = json.loads(valores[2].text)['Items'][4]['Value']['Value']
    temp_devB1 = json.loads(valores[2].text)['Items'][5]['Value']['Value']
    temp_devA2 = json.loads(valores[2].text)['Items'][6]['Value']['Value']
    temp_devA1 = json.loads(valores[2].text)['Items'][7]['Value']['Value']
    temp_descB = json.loads(valores[2].text)['Items'][8]['Value']['Value']
    temp_descA = json.loads(valores[2].text)['Items'][9]['Value']['Value']
    pump_run = json.loads(valores[2].text)['Items'][10]['Value']['Value']
    pot_act = json.loads(valores[2].text)['Items'][11]['Value']['Value']
    hor_total = json.loads(valores[2].text)['Items'][12]['Value']['Value']
    hor_op = json.loads(valores[2].text)['Items'][13]['Value']['Value']
    estado = json.loads(valores[2].text)['Items'][14]['Value']['Value']
    ef_inst = json.loads(valores[2].text)['Items'][15]['Value']['Value']
    corr_C = json.loads(valores[2].text)['Items'][16]['Value']['Value']
    corr_B = json.loads(valores[2].text)['Items'][17]['Value']['Value']
    corr_A = json.loads(valores[2].text)['Items'][18]['Value']['Value']
    datos_actual_9300PP62 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_run],'Estado bomba':[estado],'Horometro total':[hor_total],
                                 'Horas operando':[hor_op],'Presion Estacion 4':[pres_est4],'Flujo':[flow],'Temperatura devanado A1':[temp_devA1],
                                 'Temperatura devanado A2':[temp_devA2],'Temperatura devanado B1':[temp_devB1], 'Temperatura devanado B2':[temp_devB2],
                                 'Temperatura devanado C1':[temp_devC1], 'Temperatura devanado C2':[temp_devC2], 'Temperatura descanso A':[temp_descA],
                                 'Temperatura descanso B':[temp_descB],'Potencia Activa':[pot_act],'Eficiencia instantanea':[ef_inst],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP62 = datos_PI_9300PP62.append(datos_actual_9300PP62,ignore_index=True)
    
    #########
    time_stamp = json.loads(valores[3].text)['Items'][0]['Value']['Timestamp']
    pres_est4 = json.loads(valores[3].text)['Items'][0]['Value']['Value']
    flow = json.loads(valores[3].text)['Items'][1]['Value']['Value']
    temp_devC2 = json.loads(valores[3].text)['Items'][2]['Value']['Value']
    temp_devC1 = json.loads(valores[3].text)['Items'][3]['Value']['Value']
    temp_devB2 = json.loads(valores[3].text)['Items'][4]['Value']['Value']
    temp_devB1 = json.loads(valores[3].text)['Items'][5]['Value']['Value']
    temp_devA2 = json.loads(valores[3].text)['Items'][6]['Value']['Value']
    temp_devA1 = json.loads(valores[3].text)['Items'][7]['Value']['Value']
    temp_descB = json.loads(valores[3].text)['Items'][8]['Value']['Value']
    temp_descA = json.loads(valores[3].text)['Items'][9]['Value']['Value']
    pump_run = json.loads(valores[3].text)['Items'][10]['Value']['Value']
    pot_act = json.loads(valores[3].text)['Items'][11]['Value']['Value']
    hor_total = json.loads(valores[3].text)['Items'][12]['Value']['Value']
    hor_op = json.loads(valores[3].text)['Items'][13]['Value']['Value']
    estado = json.loads(valores[3].text)['Items'][14]['Value']['Value']
    ef_inst = json.loads(valores[3].text)['Items'][15]['Value']['Value']
    corr_C = json.loads(valores[3].text)['Items'][16]['Value']['Value']
    corr_B = json.loads(valores[3].text)['Items'][17]['Value']['Value']
    corr_A = json.loads(valores[3].text)['Items'][18]['Value']['Value']
    datos_actual_9300PP63 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_run],'Estado bomba':[estado],'Horometro total':[hor_total],
                                 'Horas operando':[hor_op],'Presion Estacion 4':[pres_est4],'Flujo':[flow],'Temperatura devanado A1':[temp_devA1],
                                 'Temperatura devanado A2':[temp_devA2],'Temperatura devanado B1':[temp_devB1], 'Temperatura devanado B2':[temp_devB2],
                                 'Temperatura devanado C1':[temp_devC1], 'Temperatura devanado C2':[temp_devC2], 'Temperatura descanso A':[temp_descA],
                                 'Temperatura descanso B':[temp_descB],'Potencia Activa':[pot_act],'Eficiencia instantanea':[ef_inst],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP63 = datos_PI_9300PP63.append(datos_actual_9300PP63,ignore_index=True)
    
    #########
    time_stamp = json.loads(valores[4].text)['Items'][0]['Value']['Timestamp']
    pres_est4 = json.loads(valores[4].text)['Items'][0]['Value']['Value']
    flow = json.loads(valores[4].text)['Items'][1]['Value']['Value']
    temp_devC2 = json.loads(valores[4].text)['Items'][2]['Value']['Value']
    temp_devC1 = json.loads(valores[4].text)['Items'][3]['Value']['Value']
    temp_devB2 = json.loads(valores[4].text)['Items'][4]['Value']['Value']
    temp_devB1 = json.loads(valores[4].text)['Items'][5]['Value']['Value']
    temp_devA2 = json.loads(valores[4].text)['Items'][6]['Value']['Value']
    temp_devA1 = json.loads(valores[4].text)['Items'][7]['Value']['Value']
    temp_descB = json.loads(valores[4].text)['Items'][8]['Value']['Value']
    temp_descA = json.loads(valores[4].text)['Items'][9]['Value']['Value']
    pump_run = json.loads(valores[4].text)['Items'][10]['Value']['Value']
    pot_act = json.loads(valores[4].text)['Items'][11]['Value']['Value']
    hor_total = json.loads(valores[4].text)['Items'][12]['Value']['Value']
    hor_op = json.loads(valores[4].text)['Items'][13]['Value']['Value']
    estado = json.loads(valores[4].text)['Items'][14]['Value']['Value']
    ef_inst = json.loads(valores[4].text)['Items'][15]['Value']['Value']
    corr_C = json.loads(valores[4].text)['Items'][16]['Value']['Value']
    corr_B = json.loads(valores[4].text)['Items'][17]['Value']['Value']
    corr_A = json.loads(valores[4].text)['Items'][18]['Value']['Value']
    datos_actual_9300PP64 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_run],'Estado bomba':[estado],'Horometro total':[hor_total],
                                 'Horas operando':[hor_op],'Presion Estacion 4':[pres_est4],'Flujo':[flow],'Temperatura devanado A1':[temp_devA1],
                                 'Temperatura devanado A2':[temp_devA2],'Temperatura devanado B1':[temp_devB1], 'Temperatura devanado B2':[temp_devB2],
                                 'Temperatura devanado C1':[temp_devC1], 'Temperatura devanado C2':[temp_devC2], 'Temperatura descanso A':[temp_descA],
                                 'Temperatura descanso B':[temp_descB],'Potencia Activa':[pot_act],'Eficiencia instantanea':[ef_inst],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP64 = datos_PI_9300PP64.append(datos_actual_9300PP64,ignore_index=True)
    
    now = datetime.datetime.now()
    nombre_archivo = '9300V_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
    with pd.ExcelWriter('~/jupyter/Datos_Bombas/9300V/'+nombre_archivo) as writer:  
        datos_PI_9300PP60.to_excel(writer,sheet_name='PP-060')
        datos_PI_9300PP61.to_excel(writer,sheet_name='PP-061')
        datos_PI_9300PP62.to_excel(writer,sheet_name='PP-062')
        datos_PI_9300PP63.to_excel(writer,sheet_name='PP-063')
        datos_PI_9300PP64.to_excel(writer,sheet_name='PP-064')
    
    ######### 9400V ##########
    reqs = [grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwjlZ8dUmz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w5NDAwVlw5NDAwLVBQLTAxMQ/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
       grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCw1hLobEmz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w5NDAwVlw5NDAwLVBQLTAxMg/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
       grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwvBQvXkmz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w5NDAwVlw5NDAwLVBQLTAxMw/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
       grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwynLRVUmz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w5NDAwVlw5NDAwLVBQLTAxNA/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
       grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCw3l5GQEmz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w5NDAwVlw5NDAwLVBQLTAxNQ/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
       grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwQF3BlUiz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w5NDAwVlw5NDAwLVBQLTAxNg/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021'))]
    
    valores = grequests.map(reqs)

    time_stamp = json.loads(valores[0].text)['Items'][0]['Value']['Timestamp']
    corriente = json.loads(valores[0].text)['Items'][0]['Value']['Value']
    horometro = json.loads(valores[0].text)['Items'][1]['Value']['Value']
    potencia = json.loads(valores[0].text)['Items'][2]['Value']['Value']
    temp_desc_ventil = json.loads(valores[0].text)['Items'][3]['Value']['Value']
    temp_carga = json.loads(valores[0].text)['Items'][4]['Value']['Value']
    temp_dev1 = json.loads(valores[0].text)['Items'][5]['Value']['Value']
    temp_dev2 = json.loads(valores[0].text)['Items'][6]['Value']['Value']
    vdf = json.loads(valores[0].text)['Items'][7]['Value']['Value']
    velocidad = json.loads(valores[0].text)['Items'][8]['Value']['Value']
    hor_operacion = json.loads(valores[0].text)['Items'][9]['Value']['Value']
    pump_running = json.loads(valores[0].text)['Items'][10]['Value']['Value']

    datos_actual_9400PP11 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Corriente':[corriente], 'Potencia':[potencia], 'Temperatura Desc. Ventil.':[temp_desc_ventil], 'Temperatura Carga':[temp_carga],
                                         'Temperatura Devanado 1':[temp_dev1],'Temperatura Devanado 2':[temp_dev2],'VDF':[vdf],'Velocidad':[velocidad]})
    datos_PI_9400PP11 = datos_PI_9400PP11.append(datos_actual_9400PP11,ignore_index=True)

    ######
    time_stamp = json.loads(valores[1].text)['Items'][0]['Value']['Timestamp']
    corriente = json.loads(valores[1].text)['Items'][0]['Value']['Value']
    horometro = json.loads(valores[1].text)['Items'][1]['Value']['Value']
    potencia = json.loads(valores[1].text)['Items'][2]['Value']['Value']
    temp_desc_ventil = json.loads(valores[1].text)['Items'][3]['Value']['Value']
    temp_carga = json.loads(valores[1].text)['Items'][4]['Value']['Value']
    temp_dev1 = json.loads(valores[1].text)['Items'][5]['Value']['Value']
    temp_dev2 = json.loads(valores[1].text)['Items'][6]['Value']['Value']
    vdf = json.loads(valores[1].text)['Items'][7]['Value']['Value']
    velocidad = json.loads(valores[1].text)['Items'][8]['Value']['Value']
    hor_operacion = json.loads(valores[1].text)['Items'][9]['Value']['Value']
    pump_running = json.loads(valores[1].text)['Items'][10]['Value']['Value']

    datos_actual_9400PP12 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Corriente':[corriente], 'Potencia':[potencia], 'Temperatura Desc. Ventil.':[temp_desc_ventil], 'Temperatura Carga':[temp_carga],
                                         'Temperatura Devanado 1':[temp_dev1],'Temperatura Devanado 2':[temp_dev2],'VDF':[vdf],'Velocidad':[velocidad]})
    datos_PI_9400PP12 = datos_PI_9400PP12.append(datos_actual_9400PP12,ignore_index=True)
    
    ######
    time_stamp = json.loads(valores[2].text)['Items'][0]['Value']['Timestamp']
    corriente = json.loads(valores[2].text)['Items'][0]['Value']['Value']
    horometro = json.loads(valores[2].text)['Items'][1]['Value']['Value']
    potencia = json.loads(valores[2].text)['Items'][2]['Value']['Value']
    temp_desc_ventil = json.loads(valores[2].text)['Items'][3]['Value']['Value']
    temp_carga = json.loads(valores[2].text)['Items'][4]['Value']['Value']
    temp_dev1 = json.loads(valores[2].text)['Items'][5]['Value']['Value']
    temp_dev2 = json.loads(valores[2].text)['Items'][6]['Value']['Value']
    vdf = json.loads(valores[2].text)['Items'][7]['Value']['Value']
    velocidad = json.loads(valores[2].text)['Items'][8]['Value']['Value']
    hor_operacion = json.loads(valores[2].text)['Items'][9]['Value']['Value']
    pump_running = json.loads(valores[2].text)['Items'][10]['Value']['Value']

    datos_actual_9400PP13 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Corriente':[corriente], 'Potencia':[potencia], 'Temperatura Desc. Ventil.':[temp_desc_ventil], 'Temperatura Carga':[temp_carga],
                                         'Temperatura Devanado 1':[temp_dev1],'Temperatura Devanado 2':[temp_dev2],'VDF':[vdf],'Velocidad':[velocidad]})
    datos_PI_9400PP13 = datos_PI_9400PP13.append(datos_actual_9400PP13,ignore_index=True)
    
    ######
    time_stamp = json.loads(valores[3].text)['Items'][0]['Value']['Timestamp']
    corriente = json.loads(valores[3].text)['Items'][0]['Value']['Value']
    horometro = json.loads(valores[3].text)['Items'][1]['Value']['Value']
    potencia = json.loads(valores[3].text)['Items'][2]['Value']['Value']
    temp_desc_ventil = json.loads(valores[3].text)['Items'][3]['Value']['Value']
    temp_carga = json.loads(valores[3].text)['Items'][4]['Value']['Value']
    temp_dev1 = json.loads(valores[3].text)['Items'][5]['Value']['Value']
    temp_dev2 = json.loads(valores[3].text)['Items'][6]['Value']['Value']
    vdf = json.loads(valores[3].text)['Items'][7]['Value']['Value']
    velocidad = json.loads(valores[3].text)['Items'][8]['Value']['Value']
    hor_operacion = json.loads(valores[3].text)['Items'][9]['Value']['Value']
    pump_running = json.loads(valores[3].text)['Items'][10]['Value']['Value']

    datos_actual_9400PP14 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Corriente':[corriente], 'Potencia':[potencia], 'Temperatura Desc. Ventil.':[temp_desc_ventil], 'Temperatura Carga':[temp_carga],
                                         'Temperatura Devanado 1':[temp_dev1],'Temperatura Devanado 2':[temp_dev2],'VDF':[vdf],'Velocidad':[velocidad]})
    datos_PI_9400PP14 = datos_PI_9400PP14.append(datos_actual_9400PP14,ignore_index=True)
    
    ######
    time_stamp = json.loads(valores[4].text)['Items'][0]['Value']['Timestamp']
    corriente = json.loads(valores[4].text)['Items'][0]['Value']['Value']
    horometro = json.loads(valores[4].text)['Items'][1]['Value']['Value']
    potencia = json.loads(valores[4].text)['Items'][2]['Value']['Value']
    temp_desc_ventil = json.loads(valores[4].text)['Items'][3]['Value']['Value']
    temp_carga = json.loads(valores[4].text)['Items'][4]['Value']['Value']
    temp_dev1 = json.loads(valores[4].text)['Items'][5]['Value']['Value']
    temp_dev2 = json.loads(valores[4].text)['Items'][6]['Value']['Value']
    vdf = json.loads(valores[4].text)['Items'][7]['Value']['Value']
    velocidad = json.loads(valores[4].text)['Items'][8]['Value']['Value']
    hor_operacion = json.loads(valores[4].text)['Items'][9]['Value']['Value']
    pump_running = json.loads(valores[4].text)['Items'][10]['Value']['Value']

    datos_actual_9400PP15 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Corriente':[corriente], 'Potencia':[potencia], 'Temperatura Desc. Ventil.':[temp_desc_ventil], 'Temperatura Carga':[temp_carga],
                                         'Temperatura Devanado 1':[temp_dev1],'Temperatura Devanado 2':[temp_dev2],'VDF':[vdf],'Velocidad':[velocidad]})
    datos_PI_9400PP15 = datos_PI_9400PP15.append(datos_actual_9400PP15,ignore_index=True)
    
    ######
    time_stamp = json.loads(valores[5].text)['Items'][0]['Value']['Timestamp']
    corriente = json.loads(valores[5].text)['Items'][0]['Value']['Value']
    horometro = json.loads(valores[5].text)['Items'][1]['Value']['Value']
    potencia = json.loads(valores[5].text)['Items'][2]['Value']['Value']
    temp_desc_ventil = json.loads(valores[5].text)['Items'][3]['Value']['Value']
    temp_carga = json.loads(valores[5].text)['Items'][4]['Value']['Value']
    temp_dev1 = json.loads(valores[5].text)['Items'][5]['Value']['Value']
    temp_dev2 = json.loads(valores[5].text)['Items'][6]['Value']['Value']
    vdf = json.loads(valores[5].text)['Items'][7]['Value']['Value']
    velocidad = json.loads(valores[5].text)['Items'][8]['Value']['Value']
    hor_operacion = json.loads(valores[5].text)['Items'][9]['Value']['Value']
    pump_running = json.loads(valores[5].text)['Items'][10]['Value']['Value']

    datos_actual_9400PP16 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Corriente':[corriente], 'Potencia':[potencia], 'Temperatura Desc. Ventil.':[temp_desc_ventil], 'Temperatura Carga':[temp_carga],
                                         'Temperatura Devanado 1':[temp_dev1],'Temperatura Devanado 2':[temp_dev2],'VDF':[vdf],'Velocidad':[velocidad]})
    datos_PI_9400PP16 = datos_PI_9400PP16.append(datos_actual_9400PP16,ignore_index=True)

    nombre_archivo = '9400V_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
    with pd.ExcelWriter('~/jupyter/Datos_Bombas/9400V/'+nombre_archivo) as writer:  
        datos_PI_9400PP11.to_excel(writer,sheet_name='PP-011')
        datos_PI_9400PP12.to_excel(writer,sheet_name='PP-012')
        datos_PI_9400PP13.to_excel(writer,sheet_name='PP-013')
        datos_PI_9400PP14.to_excel(writer,sheet_name='PP-014')
        datos_PI_9400PP15.to_excel(writer,sheet_name='PP-015')
        datos_PI_9400PP16.to_excel(writer,sheet_name='PP-016')
        
    ######### 6650H ##########
    reqs = [grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCw6qDWlCOt6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NjUwSFw2NjUwLVBQLTAwMQ/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
       grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwIk0DICWt6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NjUwSFw2NjUwLVBQLTAwMg/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
       grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwogcYNSWt6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NjUwSFw2NjUwLVBQLTAwMw/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
       grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwsvMLSiWt6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NjUwSFw2NjUwLVBQLTAwNA/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
       grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwEjdCVyWt6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NjUwSFw2NjUwLVBQLTAwNQ/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
       grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCw8rgfXiWt6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NjUwSFw2NjUwLVBQLTAwNg/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021'))]
    valores = grequests.map(reqs)

    time_stamp = json.loads(valores[0].text)['Items'][0]['Value']['Timestamp']
    pres_bost2 = json.loads(valores[0].text)['Items'][0]['Value']['Value']
    caud_bost2 = json.loads(valores[0].text)['Items'][1]['Value']['Value']
    hor_operacion = json.loads(valores[0].text)['Items'][2]['Value']['Value']
    pump_running = json.loads(valores[0].text)['Items'][3]['Value']['Value']
    temp_dev_2c = json.loads(valores[0].text)['Items'][4]['Value']['Value']
    temp_dev_2b = json.loads(valores[0].text)['Items'][5]['Value']['Value']
    temp_dev_2a = json.loads(valores[0].text)['Items'][6]['Value']['Value']
    temp_dev_1c = json.loads(valores[0].text)['Items'][7]['Value']['Value']
    temp_dev_1b = json.loads(valores[0].text)['Items'][8]['Value']['Value']
    temp_dev_1a = json.loads(valores[0].text)['Items'][9]['Value']['Value']
    temp_desc_b = json.loads(valores[0].text)['Items'][10]['Value']['Value']
    temp_desc_a = json.loads(valores[0].text)['Items'][11]['Value']['Value']
    pot_act = json.loads(valores[0].text)['Items'][12]['Value']['Value']
    horometro = json.loads(valores[0].text)['Items'][13]['Value']['Value']
    corr_c = json.loads(valores[0].text)['Items'][14]['Value']['Value']
    corr_b = json.loads(valores[0].text)['Items'][15]['Value']['Value']
    corr_a = json.loads(valores[0].text)['Items'][16]['Value']['Value']

    datos_actual_6650PP1 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Presion Booster 2':[pres_bost2],'Caudal Booster 2':[caud_bost2],'Temperatura Devanado 1A':[temp_dev_1a],
                                        'Temperatura Devanado 1B':[temp_dev_1b],'Temperatura Devanado 1C':[temp_dev_1c],'Temperatura Devanado 2A':[temp_dev_2a],
                                        'Temperatura Devanado 2B':[temp_dev_2b],'Temperatura Devanado 2C':[temp_dev_2c],'Potencia Activa':[pot_act],
                                        'Corriente A':[corr_a],'Corriente B':[corr_b],'Corriente C':[corr_c]})
    datos_PI_6650PP1 = datos_PI_6650PP1.append(datos_actual_6650PP1,ignore_index=True)

    ######
    time_stamp = json.loads(valores[1].text)['Items'][0]['Value']['Timestamp']
    pres_bost2 = json.loads(valores[1].text)['Items'][0]['Value']['Value']
    caud_bost2 = json.loads(valores[1].text)['Items'][1]['Value']['Value']
    hor_operacion = json.loads(valores[1].text)['Items'][2]['Value']['Value']
    pump_running = json.loads(valores[1].text)['Items'][3]['Value']['Value']
    temp_dev_2c = json.loads(valores[1].text)['Items'][4]['Value']['Value']
    temp_dev_2b = json.loads(valores[1].text)['Items'][5]['Value']['Value']
    temp_dev_2a = json.loads(valores[1].text)['Items'][6]['Value']['Value']
    temp_dev_1c = json.loads(valores[1].text)['Items'][7]['Value']['Value']
    temp_dev_1b = json.loads(valores[1].text)['Items'][8]['Value']['Value']
    temp_dev_1a = json.loads(valores[1].text)['Items'][9]['Value']['Value']
    temp_desc_b = json.loads(valores[1].text)['Items'][10]['Value']['Value']
    temp_desc_a = json.loads(valores[1].text)['Items'][11]['Value']['Value']
    pot_act = json.loads(valores[1].text)['Items'][12]['Value']['Value']
    horometro = json.loads(valores[1].text)['Items'][13]['Value']['Value']
    corr_c = json.loads(valores[1].text)['Items'][14]['Value']['Value']
    corr_b = json.loads(valores[1].text)['Items'][15]['Value']['Value']
    corr_a = json.loads(valores[1].text)['Items'][16]['Value']['Value']

    datos_actual_6650PP2 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Presion Booster 2':[pres_bost2],'Caudal Booster 2':[caud_bost2],'Temperatura Devanado 1A':[temp_dev_1a],
                                        'Temperatura Devanado 1B':[temp_dev_1b],'Temperatura Devanado 1C':[temp_dev_1c],'Temperatura Devanado 2A':[temp_dev_2a],
                                        'Temperatura Devanado 2B':[temp_dev_2b],'Temperatura Devanado 2C':[temp_dev_2c],'Potencia Activa':[pot_act],
                                        'Corriente A':[corr_a],'Corriente B':[corr_b],'Corriente C':[corr_c]})
    datos_PI_6650PP2 = datos_PI_6650PP2.append(datos_actual_6650PP2,ignore_index=True)
    
    ######
    time_stamp = json.loads(valores[2].text)['Items'][0]['Value']['Timestamp']
    pres_bost2 = json.loads(valores[2].text)['Items'][0]['Value']['Value']
    caud_bost2 = json.loads(valores[2].text)['Items'][1]['Value']['Value']
    hor_operacion = json.loads(valores[2].text)['Items'][2]['Value']['Value']
    pump_running = json.loads(valores[2].text)['Items'][3]['Value']['Value']
    temp_dev_2c = json.loads(valores[2].text)['Items'][4]['Value']['Value']
    temp_dev_2b = json.loads(valores[2].text)['Items'][5]['Value']['Value']
    temp_dev_2a = json.loads(valores[2].text)['Items'][6]['Value']['Value']
    temp_dev_1c = json.loads(valores[2].text)['Items'][7]['Value']['Value']
    temp_dev_1b = json.loads(valores[2].text)['Items'][8]['Value']['Value']
    temp_dev_1a = json.loads(valores[2].text)['Items'][9]['Value']['Value']
    temp_desc_b = json.loads(valores[2].text)['Items'][10]['Value']['Value']
    temp_desc_a = json.loads(valores[2].text)['Items'][11]['Value']['Value']
    pot_act = json.loads(valores[2].text)['Items'][12]['Value']['Value']
    horometro = json.loads(valores[2].text)['Items'][13]['Value']['Value']
    corr_c = json.loads(valores[2].text)['Items'][14]['Value']['Value']
    corr_b = json.loads(valores[2].text)['Items'][15]['Value']['Value']
    corr_a = json.loads(valores[2].text)['Items'][16]['Value']['Value']

    datos_actual_6650PP3 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Presion Booster 2':[pres_bost2],'Caudal Booster 2':[caud_bost2],'Temperatura Devanado 1A':[temp_dev_1a],
                                        'Temperatura Devanado 1B':[temp_dev_1b],'Temperatura Devanado 1C':[temp_dev_1c],'Temperatura Devanado 2A':[temp_dev_2a],
                                        'Temperatura Devanado 2B':[temp_dev_2b],'Temperatura Devanado 2C':[temp_dev_2c],'Potencia Activa':[pot_act],
                                        'Corriente A':[corr_a],'Corriente B':[corr_b],'Corriente C':[corr_c]})
    datos_PI_6650PP3 = datos_PI_6650PP3.append(datos_actual_6650PP3,ignore_index=True)
    
    ######
    time_stamp = json.loads(valores[3].text)['Items'][0]['Value']['Timestamp']
    pres_bost2 = json.loads(valores[3].text)['Items'][0]['Value']['Value']
    caud_bost2 = json.loads(valores[3].text)['Items'][1]['Value']['Value']
    hor_operacion = json.loads(valores[3].text)['Items'][2]['Value']['Value']
    pump_running = json.loads(valores[3].text)['Items'][3]['Value']['Value']
    temp_dev_2c = json.loads(valores[3].text)['Items'][4]['Value']['Value']
    temp_dev_2b = json.loads(valores[3].text)['Items'][5]['Value']['Value']
    temp_dev_2a = json.loads(valores[3].text)['Items'][6]['Value']['Value']
    temp_dev_1c = json.loads(valores[3].text)['Items'][7]['Value']['Value']
    temp_dev_1b = json.loads(valores[3].text)['Items'][8]['Value']['Value']
    temp_dev_1a = json.loads(valores[3].text)['Items'][9]['Value']['Value']
    temp_desc_b = json.loads(valores[3].text)['Items'][10]['Value']['Value']
    temp_desc_a = json.loads(valores[3].text)['Items'][11]['Value']['Value']
    pot_act = json.loads(valores[3].text)['Items'][12]['Value']['Value']
    horometro = json.loads(valores[3].text)['Items'][13]['Value']['Value']
    corr_c = json.loads(valores[3].text)['Items'][14]['Value']['Value']
    corr_b = json.loads(valores[3].text)['Items'][15]['Value']['Value']
    corr_a = json.loads(valores[3].text)['Items'][16]['Value']['Value']

    datos_actual_6650PP4 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Presion Booster 2':[pres_bost2],'Caudal Booster 2':[caud_bost2],'Temperatura Devanado 1A':[temp_dev_1a],
                                        'Temperatura Devanado 1B':[temp_dev_1b],'Temperatura Devanado 1C':[temp_dev_1c],'Temperatura Devanado 2A':[temp_dev_2a],
                                        'Temperatura Devanado 2B':[temp_dev_2b],'Temperatura Devanado 2C':[temp_dev_2c],'Potencia Activa':[pot_act],
                                        'Corriente A':[corr_a],'Corriente B':[corr_b],'Corriente C':[corr_c]})
    datos_PI_6650PP4 = datos_PI_6650PP4.append(datos_actual_6650PP4,ignore_index=True)
    
    ######
    time_stamp = json.loads(valores[4].text)['Items'][0]['Value']['Timestamp']
    pres_bost2 = json.loads(valores[4].text)['Items'][0]['Value']['Value']
    caud_bost2 = json.loads(valores[4].text)['Items'][1]['Value']['Value']
    hor_operacion = json.loads(valores[4].text)['Items'][2]['Value']['Value']
    pump_running = json.loads(valores[4].text)['Items'][3]['Value']['Value']
    temp_dev_2c = json.loads(valores[4].text)['Items'][4]['Value']['Value']
    temp_dev_2b = json.loads(valores[4].text)['Items'][5]['Value']['Value']
    temp_dev_2a = json.loads(valores[4].text)['Items'][6]['Value']['Value']
    temp_dev_1c = json.loads(valores[4].text)['Items'][7]['Value']['Value']
    temp_dev_1b = json.loads(valores[4].text)['Items'][8]['Value']['Value']
    temp_dev_1a = json.loads(valores[4].text)['Items'][9]['Value']['Value']
    temp_desc_b = json.loads(valores[4].text)['Items'][10]['Value']['Value']
    temp_desc_a = json.loads(valores[4].text)['Items'][11]['Value']['Value']
    pot_act = json.loads(valores[4].text)['Items'][12]['Value']['Value']
    horometro = json.loads(valores[4].text)['Items'][13]['Value']['Value']
    corr_c = json.loads(valores[4].text)['Items'][14]['Value']['Value']
    corr_b = json.loads(valores[4].text)['Items'][15]['Value']['Value']
    corr_a = json.loads(valores[4].text)['Items'][16]['Value']['Value']

    datos_actual_6650PP5 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Presion Booster 2':[pres_bost2],'Caudal Booster 2':[caud_bost2],'Temperatura Devanado 1A':[temp_dev_1a],
                                        'Temperatura Devanado 1B':[temp_dev_1b],'Temperatura Devanado 1C':[temp_dev_1c],'Temperatura Devanado 2A':[temp_dev_2a],
                                        'Temperatura Devanado 2B':[temp_dev_2b],'Temperatura Devanado 2C':[temp_dev_2c],'Potencia Activa':[pot_act],
                                        'Corriente A':[corr_a],'Corriente B':[corr_b],'Corriente C':[corr_c]})
    datos_PI_6650PP5 = datos_PI_6650PP5.append(datos_actual_6650PP5,ignore_index=True)
    
    ######
    time_stamp = json.loads(valores[5].text)['Items'][0]['Value']['Timestamp']
    pres_bost2 = json.loads(valores[5].text)['Items'][0]['Value']['Value']
    caud_bost2 = json.loads(valores[5].text)['Items'][1]['Value']['Value']
    hor_operacion = json.loads(valores[5].text)['Items'][2]['Value']['Value']
    pump_running = json.loads(valores[5].text)['Items'][3]['Value']['Value']
    temp_dev_2c = json.loads(valores[5].text)['Items'][4]['Value']['Value']
    temp_dev_2b = json.loads(valores[5].text)['Items'][5]['Value']['Value']
    temp_dev_2a = json.loads(valores[5].text)['Items'][6]['Value']['Value']
    temp_dev_1c = json.loads(valores[5].text)['Items'][7]['Value']['Value']
    temp_dev_1b = json.loads(valores[5].text)['Items'][8]['Value']['Value']
    temp_dev_1a = json.loads(valores[5].text)['Items'][9]['Value']['Value']
    temp_desc_b = json.loads(valores[5].text)['Items'][10]['Value']['Value']
    temp_desc_a = json.loads(valores[5].text)['Items'][11]['Value']['Value']
    pot_act = json.loads(valores[5].text)['Items'][12]['Value']['Value']
    horometro = json.loads(valores[5].text)['Items'][13]['Value']['Value']
    corr_c = json.loads(valores[5].text)['Items'][14]['Value']['Value']
    corr_b = json.loads(valores[5].text)['Items'][15]['Value']['Value']
    corr_a = json.loads(valores[5].text)['Items'][16]['Value']['Value']

    datos_actual_6650PP6 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Presion Booster 2':[pres_bost2],'Caudal Booster 2':[caud_bost2],'Temperatura Devanado 1A':[temp_dev_1a],
                                        'Temperatura Devanado 1B':[temp_dev_1b],'Temperatura Devanado 1C':[temp_dev_1c],'Temperatura Devanado 2A':[temp_dev_2a],
                                        'Temperatura Devanado 2B':[temp_dev_2b],'Temperatura Devanado 2C':[temp_dev_2c],'Potencia Activa':[pot_act],
                                        'Corriente A':[corr_a],'Corriente B':[corr_b],'Corriente C':[corr_c]})
    datos_PI_6650PP6 = datos_PI_6650PP6.append(datos_actual_6650PP6,ignore_index=True)
    
    nombre_archivo = '6650H_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
    with pd.ExcelWriter('~/jupyter/Datos_Bombas/6650H/'+nombre_archivo) as writer:  
        datos_PI_6650PP1.to_excel(writer,sheet_name='PP-001')
        datos_PI_6650PP2.to_excel(writer,sheet_name='PP-002')
        datos_PI_6650PP3.to_excel(writer,sheet_name='PP-003')
        datos_PI_6650PP4.to_excel(writer,sheet_name='PP-004')
        datos_PI_6650PP5.to_excel(writer,sheet_name='PP-005')
        datos_PI_6650PP6.to_excel(writer,sheet_name='PP-006')
    
    ######### 6650V ##########
    reqs = [grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwQj8EaEyz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NjUwVlw2NjUwLVBQLTAxMw/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
           grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwgEwnd0yz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NjUwVlw2NjUwLVBQLTAxNA/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
           grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwZXx3gUyz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NjUwVlw2NjUwLVBQLTAxNQ/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
           grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCw1bK0iEyz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NjUwVlw2NjUwLVBQLTAxNg/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
           grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwwexllUyz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NjUwVlw2NjUwLVBQLTAxNw/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
           grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwbEiRnEyz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NjUwVlw2NjUwLVBQLTAxOA/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
           grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwDMGuo0yz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NjUwVlw2NjUwLVBQLTAxOQ/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
           grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCw0J1OrEyz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NjUwVlw2NjUwLVBQLTAyMA/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
           grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwm9rItUyz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NjUwVlw2NjUwLVBQLTAyMQ/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
           grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwdrlOxEyz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NjUwVlw2NjUwLVBQLTAyMg/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
           grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwlVlFzEyz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NjUwVlw2NjUwLVBQLTAyMw/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
           grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwYKic00yz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NjUwVlw2NjUwLVBQLTAyNA/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),]
    valores = grequests.map(reqs)
    time_stamp = json.loads(valores[0].text)['Items'][0]['Value']['Timestamp']
    pres_imp = json.loads(valores[0].text)['Items'][0]['Value']['Value']
    caud_reimp = json.loads(valores[0].text)['Items'][1]['Value']['Value']
    hor_operacion = json.loads(valores[0].text)['Items'][2]['Value']['Value']
    pump_running = json.loads(valores[0].text)['Items'][3]['Value']['Value']
    pot = json.loads(valores[0].text)['Items'][4]['Value']['Value']
    horometro = json.loads(valores[0].text)['Items'][5]['Value']['Value']
    corr = json.loads(valores[0].text)['Items'][6]['Value']['Value']

    datos_actual_6650PP13 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Presion Impulsion':[pres_imp],'Caudal Reimpulsion':[caud_reimp],'Potencia':[pot],'Corriente':[corr]})
    datos_PI_6650PP13 = datos_PI_6650PP13.append(datos_actual_6650PP13,ignore_index=True)

    #####
    time_stamp = json.loads(valores[1].text)['Items'][0]['Value']['Timestamp']
    pres_imp = json.loads(valores[1].text)['Items'][0]['Value']['Value']
    caud_reimp = json.loads(valores[1].text)['Items'][1]['Value']['Value']
    hor_operacion = json.loads(valores[1].text)['Items'][2]['Value']['Value']
    pump_running = json.loads(valores[1].text)['Items'][3]['Value']['Value']
    pot = json.loads(valores[1].text)['Items'][4]['Value']['Value']
    horometro = json.loads(valores[1].text)['Items'][5]['Value']['Value']
    corr = json.loads(valores[1].text)['Items'][6]['Value']['Value']

    datos_actual_6650PP14 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Presion Impulsion':[pres_imp],'Caudal Reimpulsion':[caud_reimp],'Potencia':[pot],'Corriente':[corr]})
    datos_PI_6650PP14 = datos_PI_6650PP14.append(datos_actual_6650PP14,ignore_index=True)

    #####
    time_stamp = json.loads(valores[2].text)['Items'][0]['Value']['Timestamp']
    pres_imp = json.loads(valores[2].text)['Items'][0]['Value']['Value']
    caud_reimp = json.loads(valores[2].text)['Items'][1]['Value']['Value']
    hor_operacion = json.loads(valores[2].text)['Items'][2]['Value']['Value']
    pump_running = json.loads(valores[2].text)['Items'][3]['Value']['Value']
    pot = json.loads(valores[2].text)['Items'][4]['Value']['Value']
    horometro = json.loads(valores[2].text)['Items'][5]['Value']['Value']
    corr = json.loads(valores[2].text)['Items'][6]['Value']['Value']

    datos_actual_6650PP15 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Presion Impulsion':[pres_imp],'Caudal Reimpulsion':[caud_reimp],'Potencia':[pot],'Corriente':[corr]})
    datos_PI_6650PP15 = datos_PI_6650PP15.append(datos_actual_6650PP15,ignore_index=True)

    #####
    time_stamp = json.loads(valores[3].text)['Items'][0]['Value']['Timestamp']
    pres_imp = json.loads(valores[3].text)['Items'][0]['Value']['Value']
    caud_reimp = json.loads(valores[3].text)['Items'][1]['Value']['Value']
    hor_operacion = json.loads(valores[3].text)['Items'][2]['Value']['Value']
    pump_running = json.loads(valores[3].text)['Items'][3]['Value']['Value']
    pot = json.loads(valores[3].text)['Items'][4]['Value']['Value']
    horometro = json.loads(valores[3].text)['Items'][5]['Value']['Value']
    corr = json.loads(valores[3].text)['Items'][6]['Value']['Value']

    datos_actual_6650PP16 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Presion Impulsion':[pres_imp],'Caudal Reimpulsion':[caud_reimp],'Potencia':[pot],'Corriente':[corr]})
    datos_PI_6650PP16 = datos_PI_6650PP16.append(datos_actual_6650PP16,ignore_index=True)

    #####
    time_stamp = json.loads(valores[4].text)['Items'][0]['Value']['Timestamp']
    pres_imp = json.loads(valores[4].text)['Items'][0]['Value']['Value']
    caud_reimp = json.loads(valores[4].text)['Items'][1]['Value']['Value']
    hor_operacion = json.loads(valores[4].text)['Items'][2]['Value']['Value']
    pump_running = json.loads(valores[4].text)['Items'][3]['Value']['Value']
    pot = json.loads(valores[4].text)['Items'][4]['Value']['Value']
    horometro = json.loads(valores[4].text)['Items'][5]['Value']['Value']
    corr = json.loads(valores[4].text)['Items'][6]['Value']['Value']

    datos_actual_6650PP17 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Presion Impulsion':[pres_imp],'Caudal Reimpulsion':[caud_reimp],'Potencia':[pot],'Corriente':[corr]})
    datos_PI_6650PP17 = datos_PI_6650PP17.append(datos_actual_6650PP17,ignore_index=True)

    #####
    time_stamp = json.loads(valores[5].text)['Items'][0]['Value']['Timestamp']
    pres_imp = json.loads(valores[5].text)['Items'][0]['Value']['Value']
    caud_reimp = json.loads(valores[5].text)['Items'][1]['Value']['Value']
    hor_operacion = json.loads(valores[5].text)['Items'][2]['Value']['Value']
    pump_running = json.loads(valores[5].text)['Items'][3]['Value']['Value']
    pot = json.loads(valores[5].text)['Items'][4]['Value']['Value']
    horometro = json.loads(valores[5].text)['Items'][5]['Value']['Value']
    corr = json.loads(valores[5].text)['Items'][6]['Value']['Value']

    datos_actual_6650PP18 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Presion Impulsion':[pres_imp],'Caudal Reimpulsion':[caud_reimp],'Potencia':[pot],'Corriente':[corr]})
    datos_PI_6650PP18 = datos_PI_6650PP18.append(datos_actual_6650PP18,ignore_index=True)

    #####
    time_stamp = json.loads(valores[6].text)['Items'][0]['Value']['Timestamp']
    pres_imp = json.loads(valores[6].text)['Items'][0]['Value']['Value']
    caud_reimp = json.loads(valores[6].text)['Items'][1]['Value']['Value']
    hor_operacion = json.loads(valores[6].text)['Items'][2]['Value']['Value']
    pump_running = json.loads(valores[6].text)['Items'][3]['Value']['Value']
    pot = json.loads(valores[6].text)['Items'][4]['Value']['Value']
    horometro = json.loads(valores[6].text)['Items'][5]['Value']['Value']
    corr = json.loads(valores[6].text)['Items'][6]['Value']['Value']

    datos_actual_6650PP19 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Presion Impulsion':[pres_imp],'Caudal Reimpulsion':[caud_reimp],'Potencia':[pot],'Corriente':[corr]})
    datos_PI_6650PP19 = datos_PI_6650PP19.append(datos_actual_6650PP19,ignore_index=True)

    #####
    time_stamp = json.loads(valores[7].text)['Items'][0]['Value']['Timestamp']
    pres_imp = json.loads(valores[7].text)['Items'][0]['Value']['Value']
    caud_reimp = json.loads(valores[7].text)['Items'][1]['Value']['Value']
    hor_operacion = json.loads(valores[7].text)['Items'][2]['Value']['Value']
    pump_running = json.loads(valores[7].text)['Items'][3]['Value']['Value']
    pot = json.loads(valores[7].text)['Items'][4]['Value']['Value']
    horometro = json.loads(valores[7].text)['Items'][5]['Value']['Value']
    corr = json.loads(valores[7].text)['Items'][6]['Value']['Value']
    
    datos_actual_6650PP20 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Presion Impulsion':[pres_imp],'Caudal Reimpulsion':[caud_reimp],'Potencia':[pot],'Corriente':[corr]})
    datos_PI_6650PP20 = datos_PI_6650PP20.append(datos_actual_6650PP20,ignore_index=True)

    #####
    time_stamp = json.loads(valores[8].text)['Items'][0]['Value']['Timestamp']
    pres_imp = json.loads(valores[8].text)['Items'][0]['Value']['Value']
    caud_reimp = json.loads(valores[8].text)['Items'][1]['Value']['Value']
    hor_operacion = json.loads(valores[8].text)['Items'][2]['Value']['Value']
    pump_running = json.loads(valores[8].text)['Items'][3]['Value']['Value']
    pot = json.loads(valores[8].text)['Items'][4]['Value']['Value']
    horometro = json.loads(valores[8].text)['Items'][5]['Value']['Value']
    corr = json.loads(valores[8].text)['Items'][6]['Value']['Value']

    datos_actual_6650PP21 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Presion Impulsion':[pres_imp],'Caudal Reimpulsion':[caud_reimp],'Potencia':[pot],'Corriente':[corr]})
    datos_PI_6650PP21 = datos_PI_6650PP21.append(datos_actual_6650PP21,ignore_index=True)

    #####
    time_stamp = json.loads(valores[9].text)['Items'][0]['Value']['Timestamp']
    pres_imp = json.loads(valores[9].text)['Items'][0]['Value']['Value']
    caud_reimp = json.loads(valores[9].text)['Items'][1]['Value']['Value']
    hor_operacion = json.loads(valores[9].text)['Items'][2]['Value']['Value']
    pump_running = json.loads(valores[9].text)['Items'][3]['Value']['Value']
    pot = json.loads(valores[9].text)['Items'][4]['Value']['Value']
    horometro = json.loads(valores[9].text)['Items'][5]['Value']['Value']
    corr = json.loads(valores[9].text)['Items'][6]['Value']['Value']

    datos_actual_6650PP22 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Presion Impulsion':[pres_imp],'Caudal Reimpulsion':[caud_reimp],'Potencia':[pot],'Corriente':[corr]})
    datos_PI_6650PP22 = datos_PI_6650PP22.append(datos_actual_6650PP22,ignore_index=True)

    #####
    time_stamp = json.loads(valores[10].text)['Items'][0]['Value']['Timestamp']
    pres_imp = json.loads(valores[10].text)['Items'][0]['Value']['Value']
    caud_reimp = json.loads(valores[10].text)['Items'][1]['Value']['Value']
    hor_operacion = json.loads(valores[10].text)['Items'][2]['Value']['Value']
    pump_running = json.loads(valores[10].text)['Items'][3]['Value']['Value']
    pot = json.loads(valores[10].text)['Items'][4]['Value']['Value']
    horometro = json.loads(valores[10].text)['Items'][5]['Value']['Value']
    corr = json.loads(valores[10].text)['Items'][6]['Value']['Value']

    datos_actual_6650PP23 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Presion Impulsion':[pres_imp],'Caudal Reimpulsion':[caud_reimp],'Potencia':[pot],'Corriente':[corr]})
    datos_PI_6650PP23 = datos_PI_6650PP23.append(datos_actual_6650PP23,ignore_index=True)

    #####
    time_stamp = json.loads(valores[11].text)['Items'][0]['Value']['Timestamp']
    pres_imp = json.loads(valores[11].text)['Items'][0]['Value']['Value']
    caud_reimp = json.loads(valores[11].text)['Items'][1]['Value']['Value']
    hor_operacion = json.loads(valores[11].text)['Items'][2]['Value']['Value']
    pump_running = json.loads(valores[11].text)['Items'][3]['Value']['Value']
    pot = json.loads(valores[11].text)['Items'][4]['Value']['Value']
    horometro = json.loads(valores[11].text)['Items'][5]['Value']['Value']
    corr = json.loads(valores[11].text)['Items'][6]['Value']['Value']

    datos_actual_6650PP24 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                         'Presion Impulsion':[pres_imp],'Caudal Reimpulsion':[caud_reimp],'Potencia':[pot],'Corriente':[corr]})
    datos_PI_6650PP24 = datos_PI_6650PP24.append(datos_actual_6650PP24,ignore_index=True)
    
    nombre_archivo = '6650V_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
    with pd.ExcelWriter('~/jupyter/Datos_Bombas/6650V/'+nombre_archivo) as writer:  
        datos_PI_6650PP13.to_excel(writer,sheet_name='PP-013')
        datos_PI_6650PP14.to_excel(writer,sheet_name='PP-014')
        datos_PI_6650PP15.to_excel(writer,sheet_name='PP-015')
        datos_PI_6650PP16.to_excel(writer,sheet_name='PP-016')
        datos_PI_6650PP17.to_excel(writer,sheet_name='PP-017')
        datos_PI_6650PP18.to_excel(writer,sheet_name='PP-018')
        datos_PI_6650PP19.to_excel(writer,sheet_name='PP-019')
        datos_PI_6650PP20.to_excel(writer,sheet_name='PP-020')
        datos_PI_6650PP21.to_excel(writer,sheet_name='PP-021')
        datos_PI_6650PP22.to_excel(writer,sheet_name='PP-022')
        datos_PI_6650PP23.to_excel(writer,sheet_name='PP-023')
        datos_PI_6650PP24.to_excel(writer,sheet_name='PP-024')
    
    ######### 6750H ##########
    reqs = [grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwghZ2vyWt6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NzUwSFw2NzUwLVBQLTAwOQ/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
       grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwguoQ2CWt6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NzUwSFw2NzUwLVBQLTAxMA/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
       grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwcir86SWt6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NzUwSFw2NzUwLVBQLTAxMQ/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),]
    
    valores = grequests.map(reqs)
    time_stamp = json.loads(valores[0].text)['Items'][0]['Value']['Timestamp']
    caudal_est_int = json.loads(valores[0].text)['Items'][0]['Value']['Value']    
    pres_est_int = json.loads(valores[0].text)['Items'][1]['Value']['Value']    
    hor_operacion = json.loads(valores[0].text)['Items'][2]['Value']['Value']
    temp_dev_2c = json.loads(valores[0].text)['Items'][3]['Value']['Value']
    temp_dev_2b = json.loads(valores[0].text)['Items'][4]['Value']['Value']
    temp_dev_2a = json.loads(valores[0].text)['Items'][5]['Value']['Value']
    temp_dev_1c = json.loads(valores[0].text)['Items'][6]['Value']['Value']
    temp_dev_1b = json.loads(valores[0].text)['Items'][7]['Value']['Value']
    temp_dev_1a = json.loads(valores[0].text)['Items'][8]['Value']['Value']
    temp_desc_b = json.loads(valores[0].text)['Items'][9]['Value']['Value']
    temp_desc_a = json.loads(valores[0].text)['Items'][10]['Value']['Value']
    pump_running = json.loads(valores[0].text)['Items'][11]['Value']['Value']
    pot_act = json.loads(valores[0].text)['Items'][12]['Value']['Value']
    horometro = json.loads(valores[0].text)['Items'][13]['Value']['Value']
    corr_c = json.loads(valores[0].text)['Items'][14]['Value']['Value']
    corr_b = json.loads(valores[0].text)['Items'][15]['Value']['Value']
    corr_a = json.loads(valores[0].text)['Items'][16]['Value']['Value']

    datos_actual_6750PP9 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                             'Caudal Estacion Intermedia':[caudal_est_int],'Presion Estacion Intermedia':[pres_est_int],'Temperatura Devanado 1A':[temp_dev_1a],
                                             'Temperatura Devanado 1B':[temp_dev_1b],'Temperatura Devanado 1C':[temp_dev_1c],'Temperatura Devanado 2A':[temp_dev_2a],
                                             'Temperatura Devanado 2B':[temp_dev_2b],'Temperatura Devanado 2C':[temp_dev_2c],'Temperatura Descanso A':[temp_desc_a],
                                             'Temperatura Descanso B':[temp_desc_b],'Potencia Activa':[pot_act],'Corriente A':[corr_a],'Corriente B':[corr_b],
                                             'Corriente C':[corr_c]})
    datos_PI_6750PP9 = datos_PI_6750PP9.append(datos_actual_6750PP9,ignore_index=True)
    
    #####
    time_stamp = json.loads(valores[1].text)['Items'][0]['Value']['Timestamp']
    caudal_est_int = json.loads(valores[1].text)['Items'][0]['Value']['Value']    
    pres_est_int = json.loads(valores[1].text)['Items'][1]['Value']['Value']    
    hor_operacion = json.loads(valores[1].text)['Items'][2]['Value']['Value']
    temp_dev_2c = json.loads(valores[1].text)['Items'][3]['Value']['Value']
    temp_dev_2b = json.loads(valores[1].text)['Items'][4]['Value']['Value']
    temp_dev_2a = json.loads(valores[1].text)['Items'][5]['Value']['Value']
    temp_dev_1c = json.loads(valores[1].text)['Items'][6]['Value']['Value']
    temp_dev_1b = json.loads(valores[1].text)['Items'][7]['Value']['Value']
    temp_dev_1a = json.loads(valores[1].text)['Items'][8]['Value']['Value']
    temp_desc_b = json.loads(valores[1].text)['Items'][9]['Value']['Value']
    temp_desc_a = json.loads(valores[1].text)['Items'][10]['Value']['Value']
    pump_running = json.loads(valores[1].text)['Items'][11]['Value']['Value']
    pot_act = json.loads(valores[1].text)['Items'][12]['Value']['Value']
    horometro = json.loads(valores[1].text)['Items'][13]['Value']['Value']
    corr_c = json.loads(valores[1].text)['Items'][14]['Value']['Value']
    corr_b = json.loads(valores[1].text)['Items'][15]['Value']['Value']
    corr_a = json.loads(valores[1].text)['Items'][16]['Value']['Value']

    datos_actual_6750PP10 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                             'Caudal Estacion Intermedia':[caudal_est_int],'Presion Estacion Intermedia':[pres_est_int],'Temperatura Devanado 1A':[temp_dev_1a],
                                             'Temperatura Devanado 1B':[temp_dev_1b],'Temperatura Devanado 1C':[temp_dev_1c],'Temperatura Devanado 2A':[temp_dev_2a],
                                             'Temperatura Devanado 2B':[temp_dev_2b],'Temperatura Devanado 2C':[temp_dev_2c],'Temperatura Descanso A':[temp_desc_a],
                                             'Temperatura Descanso B':[temp_desc_b],'Potencia Activa':[pot_act],'Corriente A':[corr_a],'Corriente B':[corr_b],
                                             'Corriente C':[corr_c]})
    datos_PI_6750PP10 = datos_PI_6750PP10.append(datos_actual_6750PP10,ignore_index=True)
    
    #####
    time_stamp = json.loads(valores[2].text)['Items'][0]['Value']['Timestamp']
    caudal_est_int = json.loads(valores[2].text)['Items'][0]['Value']['Value']    
    pres_est_int = json.loads(valores[2].text)['Items'][1]['Value']['Value']    
    hor_operacion = json.loads(valores[2].text)['Items'][2]['Value']['Value']
    temp_dev_2c = json.loads(valores[2].text)['Items'][3]['Value']['Value']
    temp_dev_2b = json.loads(valores[2].text)['Items'][4]['Value']['Value']
    temp_dev_2a = json.loads(valores[2].text)['Items'][5]['Value']['Value']
    temp_dev_1c = json.loads(valores[2].text)['Items'][6]['Value']['Value']
    temp_dev_1b = json.loads(valores[2].text)['Items'][7]['Value']['Value']
    temp_dev_1a = json.loads(valores[2].text)['Items'][8]['Value']['Value']
    temp_desc_b = json.loads(valores[2].text)['Items'][9]['Value']['Value']
    temp_desc_a = json.loads(valores[2].text)['Items'][10]['Value']['Value']
    pump_running = json.loads(valores[2].text)['Items'][11]['Value']['Value']
    pot_act = json.loads(valores[2].text)['Items'][12]['Value']['Value']
    horometro = json.loads(valores[2].text)['Items'][13]['Value']['Value']
    corr_c = json.loads(valores[2].text)['Items'][14]['Value']['Value']
    corr_b = json.loads(valores[2].text)['Items'][15]['Value']['Value']
    corr_a = json.loads(valores[2].text)['Items'][16]['Value']['Value']

    datos_actual_6750PP11 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                             'Caudal Estacion Intermedia':[caudal_est_int],'Presion Estacion Intermedia':[pres_est_int],'Temperatura Devanado 1A':[temp_dev_1a],
                                             'Temperatura Devanado 1B':[temp_dev_1b],'Temperatura Devanado 1C':[temp_dev_1c],'Temperatura Devanado 2A':[temp_dev_2a],
                                             'Temperatura Devanado 2B':[temp_dev_2b],'Temperatura Devanado 2C':[temp_dev_2c],'Temperatura Descanso A':[temp_desc_a],
                                             'Temperatura Descanso B':[temp_desc_b],'Potencia Activa':[pot_act],'Corriente A':[corr_a],'Corriente B':[corr_b],
                                             'Corriente C':[corr_c]})
    datos_PI_6750PP11 = datos_PI_6750PP11.append(datos_actual_6750PP11,ignore_index=True)
    
    nombre_archivo = '6750H_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
    with pd.ExcelWriter('~/jupyter/Datos_Bombas/6750H/'+nombre_archivo) as writer:  
        datos_PI_6750PP9.to_excel(writer,sheet_name='PP-009')
        datos_PI_6750PP10.to_excel(writer,sheet_name='PP-010')
        datos_PI_6750PP11.to_excel(writer,sheet_name='PP-011')
    
    ######### 6750V ##########
    reqs = [grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwt9OsDGKz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NzUwVlw2NzUwLVBQLTAwMQ/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
            grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwFxaBGGKz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NzUwVlw2NzUwLVBQLTAwMg/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
            grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwJ300KmKz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NzUwVlw2NzUwLVBQLTAwMw/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
            grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwRyG1NWKz6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1w2NzUwVlw2NzUwLVBQLTAwNA/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),]
    
    valores = grequests.map(reqs)
    time_stamp = json.loads(valores[0].text)['Items'][0]['Value']['Timestamp']
    caudal_sent_ar = json.loads(valores[0].text)['Items'][0]['Value']['Value']
    pres_imp = json.loads(valores[0].text)['Items'][1]['Value']['Value']    
    hor_operacion = json.loads(valores[0].text)['Items'][2]['Value']['Value']
    temp_dev_2c = json.loads(valores[0].text)['Items'][3]['Value']['Value']
    temp_dev_2b = json.loads(valores[0].text)['Items'][4]['Value']['Value']
    temp_dev_2a = json.loads(valores[0].text)['Items'][5]['Value']['Value']
    temp_dev_1c = json.loads(valores[0].text)['Items'][6]['Value']['Value']
    temp_dev_1b = json.loads(valores[0].text)['Items'][7]['Value']['Value']
    temp_dev_1a = json.loads(valores[0].text)['Items'][8]['Value']['Value']
    temp_desc_b = json.loads(valores[0].text)['Items'][9]['Value']['Value']
    temp_desc_a = json.loads(valores[0].text)['Items'][10]['Value']['Value']
    pump_running = json.loads(valores[0].text)['Items'][11]['Value']['Value']
    pot_act = json.loads(valores[0].text)['Items'][12]['Value']['Value']
    horometro = json.loads(valores[0].text)['Items'][13]['Value']['Value']
    corr_c = json.loads(valores[0].text)['Items'][14]['Value']['Value']
    corr_b = json.loads(valores[0].text)['Items'][15]['Value']['Value']
    corr_a = json.loads(valores[0].text)['Items'][16]['Value']['Value']

    datos_actual_6750PP1 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                             'Caudal Sentina Arenas':[caudal_sent_ar],'Presion Impulsion':[pres_imp],'Temperatura Devanado 1A':[temp_dev_1a],
                                             'Temperatura Devanado 1B':[temp_dev_1b],'Temperatura Devanado 1C':[temp_dev_1c],'Temperatura Devanado 2A':[temp_dev_2a],
                                             'Temperatura Devanado 2B':[temp_dev_2b],'Temperatura Devanado 2C':[temp_dev_2c],'Temperatura Descanso A':[temp_desc_a],
                                             'Temperatura Descanso B':[temp_desc_b],'Potencia Activa':[pot_act],'Corriente A':[corr_a],'Corriente B':[corr_b],
                                             'Corriente C':[corr_c]})
    datos_PI_6750PP1 = datos_PI_6750PP1.append(datos_actual_6750PP1,ignore_index=True)    
    
    #####
    time_stamp = json.loads(valores[1].text)['Items'][0]['Value']['Timestamp']
    caudal_sent_ar = json.loads(valores[1].text)['Items'][0]['Value']['Value']
    pres_imp = json.loads(valores[1].text)['Items'][1]['Value']['Value']    
    hor_operacion = json.loads(valores[1].text)['Items'][2]['Value']['Value']
    temp_dev_2c = json.loads(valores[1].text)['Items'][3]['Value']['Value']
    temp_dev_2b = json.loads(valores[1].text)['Items'][4]['Value']['Value']
    temp_dev_2a = json.loads(valores[1].text)['Items'][5]['Value']['Value']
    temp_dev_1c = json.loads(valores[1].text)['Items'][6]['Value']['Value']
    temp_dev_1b = json.loads(valores[1].text)['Items'][7]['Value']['Value']
    temp_dev_1a = json.loads(valores[1].text)['Items'][8]['Value']['Value']
    temp_desc_b = json.loads(valores[1].text)['Items'][9]['Value']['Value']
    temp_desc_a = json.loads(valores[1].text)['Items'][10]['Value']['Value']
    pump_running = json.loads(valores[1].text)['Items'][11]['Value']['Value']
    pot_act = json.loads(valores[1].text)['Items'][12]['Value']['Value']
    horometro = json.loads(valores[1].text)['Items'][13]['Value']['Value']
    corr_c = json.loads(valores[1].text)['Items'][14]['Value']['Value']
    corr_b = json.loads(valores[1].text)['Items'][15]['Value']['Value']
    corr_a = json.loads(valores[1].text)['Items'][16]['Value']['Value']

    datos_actual_6750PP2 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                             'Caudal Sentina Arenas':[caudal_sent_ar],'Presion Impulsion':[pres_imp],'Temperatura Devanado 1A':[temp_dev_1a],
                                             'Temperatura Devanado 1B':[temp_dev_1b],'Temperatura Devanado 1C':[temp_dev_1c],'Temperatura Devanado 2A':[temp_dev_2a],
                                             'Temperatura Devanado 2B':[temp_dev_2b],'Temperatura Devanado 2C':[temp_dev_2c],'Temperatura Descanso A':[temp_desc_a],
                                             'Temperatura Descanso B':[temp_desc_b],'Potencia Activa':[pot_act],'Corriente A':[corr_a],'Corriente B':[corr_b],
                                             'Corriente C':[corr_c]})
    datos_PI_6750PP2 = datos_PI_6750PP2.append(datos_actual_6750PP2,ignore_index=True)
    
    #####
    time_stamp = json.loads(valores[2].text)['Items'][0]['Value']['Timestamp']
    caudal_sent_ar = json.loads(valores[2].text)['Items'][0]['Value']['Value']
    pres_imp = json.loads(valores[2].text)['Items'][1]['Value']['Value']    
    hor_operacion = json.loads(valores[2].text)['Items'][2]['Value']['Value']
    temp_dev_2c = json.loads(valores[2].text)['Items'][3]['Value']['Value']
    temp_dev_2b = json.loads(valores[2].text)['Items'][4]['Value']['Value']
    temp_dev_2a = json.loads(valores[2].text)['Items'][5]['Value']['Value']
    temp_dev_1c = json.loads(valores[2].text)['Items'][6]['Value']['Value']
    temp_dev_1b = json.loads(valores[2].text)['Items'][7]['Value']['Value']
    temp_dev_1a = json.loads(valores[2].text)['Items'][8]['Value']['Value']
    temp_desc_b = json.loads(valores[2].text)['Items'][9]['Value']['Value']
    temp_desc_a = json.loads(valores[2].text)['Items'][10]['Value']['Value']
    pump_running = json.loads(valores[2].text)['Items'][11]['Value']['Value']
    pot_act = json.loads(valores[2].text)['Items'][12]['Value']['Value']
    horometro = json.loads(valores[2].text)['Items'][13]['Value']['Value']
    corr_c = json.loads(valores[2].text)['Items'][14]['Value']['Value']
    corr_b = json.loads(valores[2].text)['Items'][15]['Value']['Value']
    corr_a = json.loads(valores[2].text)['Items'][16]['Value']['Value']

    datos_actual_6750PP3 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                             'Caudal Sentina Arenas':[caudal_sent_ar],'Presion Impulsion':[pres_imp],'Temperatura Devanado 1A':[temp_dev_1a],
                                             'Temperatura Devanado 1B':[temp_dev_1b],'Temperatura Devanado 1C':[temp_dev_1c],'Temperatura Devanado 2A':[temp_dev_2a],
                                             'Temperatura Devanado 2B':[temp_dev_2b],'Temperatura Devanado 2C':[temp_dev_2c],'Temperatura Descanso A':[temp_desc_a],
                                             'Temperatura Descanso B':[temp_desc_b],'Potencia Activa':[pot_act],'Corriente A':[corr_a],'Corriente B':[corr_b],
                                             'Corriente C':[corr_c]})
    datos_PI_6750PP3 = datos_PI_6750PP3.append(datos_actual_6750PP3,ignore_index=True)
    
    #####
    time_stamp = json.loads(valores[3].text)['Items'][0]['Value']['Timestamp']
    caudal_sent_ar = json.loads(valores[3].text)['Items'][0]['Value']['Value']
    pres_imp = json.loads(valores[3].text)['Items'][1]['Value']['Value']    
    hor_operacion = json.loads(valores[3].text)['Items'][2]['Value']['Value']
    temp_dev_2c = json.loads(valores[3].text)['Items'][3]['Value']['Value']
    temp_dev_2b = json.loads(valores[3].text)['Items'][4]['Value']['Value']
    temp_dev_2a = json.loads(valores[3].text)['Items'][5]['Value']['Value']
    temp_dev_1c = json.loads(valores[3].text)['Items'][6]['Value']['Value']
    temp_dev_1b = json.loads(valores[3].text)['Items'][7]['Value']['Value']
    temp_dev_1a = json.loads(valores[3].text)['Items'][8]['Value']['Value']
    temp_desc_b = json.loads(valores[3].text)['Items'][9]['Value']['Value']
    temp_desc_a = json.loads(valores[3].text)['Items'][10]['Value']['Value']
    pump_running = json.loads(valores[3].text)['Items'][11]['Value']['Value']
    pot_act = json.loads(valores[3].text)['Items'][12]['Value']['Value']
    horometro = json.loads(valores[3].text)['Items'][13]['Value']['Value']
    corr_c = json.loads(valores[3].text)['Items'][14]['Value']['Value']
    corr_b = json.loads(valores[3].text)['Items'][15]['Value']['Value']
    corr_a = json.loads(valores[3].text)['Items'][16]['Value']['Value']

    datos_actual_6750PP4 = pd.DataFrame({'TimeStamp':[time_stamp],'Pump Running':[pump_running], 'Horometro':[horometro], 'Horas Operacion':[hor_operacion],
                                             'Caudal Sentina Arenas':[caudal_sent_ar],'Presion Impulsion':[pres_imp],'Temperatura Devanado 1A':[temp_dev_1a],
                                             'Temperatura Devanado 1B':[temp_dev_1b],'Temperatura Devanado 1C':[temp_dev_1c],'Temperatura Devanado 2A':[temp_dev_2a],
                                             'Temperatura Devanado 2B':[temp_dev_2b],'Temperatura Devanado 2C':[temp_dev_2c],'Temperatura Descanso A':[temp_desc_a],
                                             'Temperatura Descanso B':[temp_desc_b],'Potencia Activa':[pot_act],'Corriente A':[corr_a],'Corriente B':[corr_b],
                                             'Corriente C':[corr_c]})
    datos_PI_6750PP4 = datos_PI_6750PP4.append(datos_actual_6750PP4,ignore_index=True)
    
    nombre_archivo = '6750V_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
    with pd.ExcelWriter('~/jupyter/Datos_Bombas/6750V/'+nombre_archivo) as writer:  
        datos_PI_6750PP1.to_excel(writer,sheet_name='PP-001')
        datos_PI_6750PP2.to_excel(writer,sheet_name='PP-002')
        datos_PI_6750PP3.to_excel(writer,sheet_name='PP-003')
        datos_PI_6750PP4.to_excel(writer,sheet_name='PP-004')
        
    ######### EB1 ##########
    reqs = [grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwqhOygimh6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjFcOTMwMC1QUC0wMjA/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCw-u820Smh6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjFcOTMwMC1QUC0wMjE/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwqsxi4Smh6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjFcOTMwMC1QUC0wMjI/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),]
    valores = grequests.map(reqs)

    time_stamp = json.loads(valores[0].text)['Items'][0]['Value']['Timestamp']
    pres_salida = json.loads(valores[0].text)['Items'][0]['Value']['Value']
    flow = json.loads(valores[0].text)['Items'][1]['Value']['Value']
    vib_motor_b = json.loads(valores[0].text)['Items'][2]['Value']['Value']
    vib_motor_a = json.loads(valores[0].text)['Items'][3]['Value']['Value']
    vib_bomba_b = json.loads(valores[0].text)['Items'][4]['Value']['Value']
    vib_bomba_a = json.loads(valores[0].text)['Items'][5]['Value']['Value']
    temp_b = json.loads(valores[0].text)['Items'][6]['Value']['Value']
    temp_a = json.loads(valores[0].text)['Items'][7]['Value']['Value']
    temp_dev2C = json.loads(valores[0].text)['Items'][8]['Value']['Value']
    temp_dev2B = json.loads(valores[0].text)['Items'][9]['Value']['Value']
    temp_dev2A = json.loads(valores[0].text)['Items'][10]['Value']['Value']
    temp_dev1C = json.loads(valores[0].text)['Items'][11]['Value']['Value']
    temp_dev1B = json.loads(valores[0].text)['Items'][12]['Value']['Value']
    temp_dev1A = json.loads(valores[0].text)['Items'][13]['Value']['Value']
    temp_descB = json.loads(valores[0].text)['Items'][14]['Value']['Value']
    temp_descA = json.loads(valores[0].text)['Items'][15]['Value']['Value']
    pot_act = json.loads(valores[0].text)['Items'][16]['Value']['Value']
    hor_total = json.loads(valores[0].text)['Items'][17]['Value']['Value']
    hor_op = json.loads(valores[0].text)['Items'][18]['Value']['Value']
    ef = json.loads(valores[0].text)['Items'][19]['Value']['Value']
    corr_C = json.loads(valores[0].text)['Items'][20]['Value']['Value']
    corr_B = json.loads(valores[0].text)['Items'][21]['Value']['Value']
    corr_A = json.loads(valores[0].text)['Items'][22]['Value']['Value']

    datos_actual_9300PP20 = pd.DataFrame({'TimeStamp':[time_stamp],'Horometro total':[hor_total],'Horas operando':[hor_op],
                                 'Presion Salida':[pres_salida],'Flujo':[flow],'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],'Temperatura A':[temp_a],'Temperatura B':[temp_b],                               
                                 'Temperatura devanado A1':[temp_dev1A],'Temperatura devanado A2':[temp_dev2A],
                                 'Temperatura devanado B1':[temp_dev1B],'Temperatura devanado B2':[temp_dev2C],
                                 'Temperatura devanado C1':[temp_dev1C],'Temperatura devanado C2':[temp_dev2C],
                                 'Temperatura descanso A':[temp_descA],'Temperatura descanso B':[temp_descB],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP20 = datos_PI_9300PP20.append(datos_actual_9300PP20,ignore_index=True)
    
    ######
    time_stamp = json.loads(valores[1].text)['Items'][0]['Value']['Timestamp']
    pres_salida = json.loads(valores[1].text)['Items'][0]['Value']['Value']
    flow = json.loads(valores[1].text)['Items'][1]['Value']['Value']
    vib_motor_b = json.loads(valores[1].text)['Items'][2]['Value']['Value']
    vib_motor_a = json.loads(valores[1].text)['Items'][3]['Value']['Value']
    vib_bomba_b = json.loads(valores[1].text)['Items'][4]['Value']['Value']
    vib_bomba_a = json.loads(valores[1].text)['Items'][5]['Value']['Value']
    temp_b = json.loads(valores[1].text)['Items'][6]['Value']['Value']
    temp_a = json.loads(valores[1].text)['Items'][7]['Value']['Value']
    temp_dev2C = json.loads(valores[1].text)['Items'][8]['Value']['Value']
    temp_dev2B = json.loads(valores[1].text)['Items'][9]['Value']['Value']
    temp_dev2A = json.loads(valores[1].text)['Items'][10]['Value']['Value']
    temp_dev1C = json.loads(valores[1].text)['Items'][11]['Value']['Value']
    temp_dev1B = json.loads(valores[1].text)['Items'][12]['Value']['Value']
    temp_dev1A = json.loads(valores[1].text)['Items'][13]['Value']['Value']
    temp_descB = json.loads(valores[1].text)['Items'][14]['Value']['Value']
    temp_descA = json.loads(valores[1].text)['Items'][15]['Value']['Value']
    pot_act = json.loads(valores[1].text)['Items'][16]['Value']['Value']
    hor_total = json.loads(valores[1].text)['Items'][17]['Value']['Value']
    hor_op = json.loads(valores[1].text)['Items'][18]['Value']['Value']
    ef = json.loads(valores[1].text)['Items'][19]['Value']['Value']
    corr_C = json.loads(valores[1].text)['Items'][20]['Value']['Value']
    corr_B = json.loads(valores[1].text)['Items'][21]['Value']['Value']
    corr_A = json.loads(valores[1].text)['Items'][22]['Value']['Value']

    datos_actual_9300PP21 = pd.DataFrame({'TimeStamp':[time_stamp],'Horometro total':[hor_total],'Horas operando':[hor_op],
                                 'Presion Salida':[pres_salida],'Flujo':[flow],'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],'Temperatura A':[temp_a],'Temperatura B':[temp_b],                               
                                 'Temperatura devanado A1':[temp_dev1A],'Temperatura devanado A2':[temp_dev2A],
                                 'Temperatura devanado B1':[temp_dev1B],'Temperatura devanado B2':[temp_dev2C],
                                 'Temperatura devanado C1':[temp_dev1C],'Temperatura devanado C2':[temp_dev2C],
                                 'Temperatura descanso A':[temp_descA],'Temperatura descanso B':[temp_descB],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP21 = datos_PI_9300PP21.append(datos_actual_9300PP21,ignore_index=True)
    
    ######
    time_stamp = json.loads(valores[2].text)['Items'][0]['Value']['Timestamp']
    pres_salida = json.loads(valores[2].text)['Items'][0]['Value']['Value']
    flow = json.loads(valores[2].text)['Items'][1]['Value']['Value']
    vib_motor_b = json.loads(valores[2].text)['Items'][2]['Value']['Value']
    vib_motor_a = json.loads(valores[2].text)['Items'][3]['Value']['Value']
    vib_bomba_b = json.loads(valores[2].text)['Items'][4]['Value']['Value']
    vib_bomba_a = json.loads(valores[2].text)['Items'][5]['Value']['Value']
    temp_b = json.loads(valores[2].text)['Items'][6]['Value']['Value']
    temp_a = json.loads(valores[2].text)['Items'][7]['Value']['Value']
    temp_dev2C = json.loads(valores[2].text)['Items'][8]['Value']['Value']
    temp_dev2B = json.loads(valores[2].text)['Items'][9]['Value']['Value']
    temp_dev2A = json.loads(valores[2].text)['Items'][10]['Value']['Value']
    temp_dev1C = json.loads(valores[2].text)['Items'][11]['Value']['Value']
    temp_dev1B = json.loads(valores[2].text)['Items'][12]['Value']['Value']
    temp_dev1A = json.loads(valores[2].text)['Items'][13]['Value']['Value']
    temp_descB = json.loads(valores[2].text)['Items'][14]['Value']['Value']
    temp_descA = json.loads(valores[2].text)['Items'][15]['Value']['Value']
    pot_act = json.loads(valores[2].text)['Items'][16]['Value']['Value']
    hor_total = json.loads(valores[2].text)['Items'][17]['Value']['Value']
    hor_op = json.loads(valores[2].text)['Items'][18]['Value']['Value']
    ef = json.loads(valores[2].text)['Items'][19]['Value']['Value']
    corr_C = json.loads(valores[2].text)['Items'][20]['Value']['Value']
    corr_B = json.loads(valores[2].text)['Items'][21]['Value']['Value']
    corr_A = json.loads(valores[2].text)['Items'][22]['Value']['Value']

    datos_actual_9300PP22 = pd.DataFrame({'TimeStamp':[time_stamp],'Horometro total':[hor_total],'Horas operando':[hor_op],
                                 'Presion Salida':[pres_salida],'Flujo':[flow],'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],'Temperatura A':[temp_a],'Temperatura B':[temp_b],                               
                                 'Temperatura devanado A1':[temp_dev1A],'Temperatura devanado A2':[temp_dev2A],
                                 'Temperatura devanado B1':[temp_dev1B],'Temperatura devanado B2':[temp_dev2C],
                                 'Temperatura devanado C1':[temp_dev1C],'Temperatura devanado C2':[temp_dev2C],
                                 'Temperatura descanso A':[temp_descA],'Temperatura descanso B':[temp_descB],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP22 = datos_PI_9300PP22.append(datos_actual_9300PP22,ignore_index=True)
    
    nombre_archivo = '9300_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
    with pd.ExcelWriter('~/jupyter/Datos_Bombas/EB1/'+nombre_archivo) as writer:  
        datos_PI_9300PP20.to_excel(writer,sheet_name='PP-020')
        datos_PI_9300PP21.to_excel(writer,sheet_name='PP-021')
        datos_PI_9300PP22.to_excel(writer,sheet_name='PP-022')
    
    ######### EB2 ##########
    reqs = [grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCw810A1iuh6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjJcOTMwMC1QUC0wMjU/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwqygX4iuh6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjJcOTMwMC1QUC0wMjY/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwUTfI8Cuh6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjJcOTMwMC1QUC0wMjc/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwkSm5_Cuh6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjJcOTMwMC1QUC0wMjg/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwlCm5_Cuh6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjJcOTMwMC1QUC0wMjk/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),]
    valores = grequests.map(reqs)

    time_stamp = json.loads(valores[0].text)['Items'][0]['Value']['Timestamp']
    pres_salida = json.loads(valores[0].text)['Items'][0]['Value']['Value']
    flow = json.loads(valores[0].text)['Items'][1]['Value']['Value']
    vib_motor_b = json.loads(valores[0].text)['Items'][2]['Value']['Value']
    vib_motor_a = json.loads(valores[0].text)['Items'][3]['Value']['Value']
    vib_bomba_b = json.loads(valores[0].text)['Items'][4]['Value']['Value']
    vib_bomba_a = json.loads(valores[0].text)['Items'][5]['Value']['Value']
    temp_b = json.loads(valores[0].text)['Items'][6]['Value']['Value']
    temp_a = json.loads(valores[0].text)['Items'][7]['Value']['Value']
    temp_dev2C = json.loads(valores[0].text)['Items'][8]['Value']['Value']
    temp_dev2B = json.loads(valores[0].text)['Items'][9]['Value']['Value']
    temp_dev2A = json.loads(valores[0].text)['Items'][10]['Value']['Value']
    temp_dev1C = json.loads(valores[0].text)['Items'][11]['Value']['Value']
    temp_dev1B = json.loads(valores[0].text)['Items'][12]['Value']['Value']
    temp_dev1A = json.loads(valores[0].text)['Items'][13]['Value']['Value']
    temp_descB = json.loads(valores[0].text)['Items'][14]['Value']['Value']
    temp_descA = json.loads(valores[0].text)['Items'][15]['Value']['Value']
    pot_act = json.loads(valores[0].text)['Items'][16]['Value']['Value']
    hor_total = json.loads(valores[0].text)['Items'][17]['Value']['Value']
    hor_op = json.loads(valores[0].text)['Items'][18]['Value']['Value']
    ef = json.loads(valores[0].text)['Items'][19]['Value']['Value']
    corr_C = json.loads(valores[0].text)['Items'][20]['Value']['Value']
    corr_B = json.loads(valores[0].text)['Items'][21]['Value']['Value']
    corr_A = json.loads(valores[0].text)['Items'][22]['Value']['Value']

    datos_actual_9300PP25 = pd.DataFrame({'TimeStamp':[time_stamp],'Horometro total':[hor_total],'Horas operando':[hor_op],
                                 'Presion Salida':[pres_salida],'Flujo':[flow],'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],'Temperatura A':[temp_a],'Temperatura B':[temp_b],                               
                                 'Temperatura devanado A1':[temp_dev1A],'Temperatura devanado A2':[temp_dev2A],
                                 'Temperatura devanado B1':[temp_dev1B],'Temperatura devanado B2':[temp_dev2C],
                                 'Temperatura devanado C1':[temp_dev1C],'Temperatura devanado C2':[temp_dev2C],
                                 'Temperatura descanso A':[temp_descA],'Temperatura descanso B':[temp_descB],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP25 = datos_PI_9300PP25.append(datos_actual_9300PP25,ignore_index=True)
    
    ######
    time_stamp = json.loads(valores[1].text)['Items'][0]['Value']['Timestamp']
    pres_salida = json.loads(valores[1].text)['Items'][0]['Value']['Value']
    flow = json.loads(valores[1].text)['Items'][1]['Value']['Value']
    vib_motor_b = json.loads(valores[1].text)['Items'][2]['Value']['Value']
    vib_motor_a = json.loads(valores[1].text)['Items'][3]['Value']['Value']
    vib_bomba_b = json.loads(valores[1].text)['Items'][4]['Value']['Value']
    vib_bomba_a = json.loads(valores[1].text)['Items'][5]['Value']['Value']
    temp_b = json.loads(valores[1].text)['Items'][6]['Value']['Value']
    temp_a = json.loads(valores[1].text)['Items'][7]['Value']['Value']
    temp_dev2C = json.loads(valores[1].text)['Items'][8]['Value']['Value']
    temp_dev2B = json.loads(valores[1].text)['Items'][9]['Value']['Value']
    temp_dev2A = json.loads(valores[1].text)['Items'][10]['Value']['Value']
    temp_dev1C = json.loads(valores[1].text)['Items'][11]['Value']['Value']
    temp_dev1B = json.loads(valores[1].text)['Items'][12]['Value']['Value']
    temp_dev1A = json.loads(valores[1].text)['Items'][13]['Value']['Value']
    temp_descB = json.loads(valores[1].text)['Items'][14]['Value']['Value']
    temp_descA = json.loads(valores[1].text)['Items'][15]['Value']['Value']
    pot_act = json.loads(valores[1].text)['Items'][16]['Value']['Value']
    hor_total = json.loads(valores[1].text)['Items'][17]['Value']['Value']
    hor_op = json.loads(valores[1].text)['Items'][18]['Value']['Value']
    ef = json.loads(valores[1].text)['Items'][19]['Value']['Value']
    corr_C = json.loads(valores[1].text)['Items'][20]['Value']['Value']
    corr_B = json.loads(valores[1].text)['Items'][21]['Value']['Value']
    corr_A = json.loads(valores[1].text)['Items'][22]['Value']['Value']

    datos_actual_9300PP26 = pd.DataFrame({'TimeStamp':[time_stamp],'Horometro total':[hor_total],'Horas operando':[hor_op],
                                 'Presion Salida':[pres_salida],'Flujo':[flow],'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],'Temperatura A':[temp_a],'Temperatura B':[temp_b],                               
                                 'Temperatura devanado A1':[temp_dev1A],'Temperatura devanado A2':[temp_dev2A],
                                 'Temperatura devanado B1':[temp_dev1B],'Temperatura devanado B2':[temp_dev2C],
                                 'Temperatura devanado C1':[temp_dev1C],'Temperatura devanado C2':[temp_dev2C],
                                 'Temperatura descanso A':[temp_descA],'Temperatura descanso B':[temp_descB],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP26 = datos_PI_9300PP26.append(datos_actual_9300PP26,ignore_index=True)
    
    ######
    time_stamp = json.loads(valores[2].text)['Items'][0]['Value']['Timestamp']
    pres_salida = json.loads(valores[2].text)['Items'][0]['Value']['Value']
    flow = json.loads(valores[2].text)['Items'][1]['Value']['Value']
    vib_motor_b = json.loads(valores[2].text)['Items'][2]['Value']['Value']
    vib_motor_a = json.loads(valores[2].text)['Items'][3]['Value']['Value']
    vib_bomba_b = json.loads(valores[2].text)['Items'][4]['Value']['Value']
    vib_bomba_a = json.loads(valores[2].text)['Items'][5]['Value']['Value']
    temp_b = json.loads(valores[2].text)['Items'][6]['Value']['Value']
    temp_a = json.loads(valores[2].text)['Items'][7]['Value']['Value']
    temp_dev2C = json.loads(valores[2].text)['Items'][8]['Value']['Value']
    temp_dev2B = json.loads(valores[2].text)['Items'][9]['Value']['Value']
    temp_dev2A = json.loads(valores[2].text)['Items'][10]['Value']['Value']
    temp_dev1C = json.loads(valores[2].text)['Items'][11]['Value']['Value']
    temp_dev1B = json.loads(valores[2].text)['Items'][12]['Value']['Value']
    temp_dev1A = json.loads(valores[2].text)['Items'][13]['Value']['Value']
    temp_descB = json.loads(valores[2].text)['Items'][14]['Value']['Value']
    temp_descA = json.loads(valores[2].text)['Items'][15]['Value']['Value']
    pot_act = json.loads(valores[2].text)['Items'][16]['Value']['Value']
    hor_total = json.loads(valores[2].text)['Items'][17]['Value']['Value']
    hor_op = json.loads(valores[2].text)['Items'][18]['Value']['Value']
    ef = json.loads(valores[2].text)['Items'][19]['Value']['Value']
    corr_C = json.loads(valores[2].text)['Items'][20]['Value']['Value']
    corr_B = json.loads(valores[2].text)['Items'][21]['Value']['Value']
    corr_A = json.loads(valores[2].text)['Items'][22]['Value']['Value']

    datos_actual_9300PP27 = pd.DataFrame({'TimeStamp':[time_stamp],'Horometro total':[hor_total],'Horas operando':[hor_op],
                                 'Presion Salida':[pres_salida],'Flujo':[flow],'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],'Temperatura A':[temp_a],'Temperatura B':[temp_b],                               
                                 'Temperatura devanado A1':[temp_dev1A],'Temperatura devanado A2':[temp_dev2A],
                                 'Temperatura devanado B1':[temp_dev1B],'Temperatura devanado B2':[temp_dev2C],
                                 'Temperatura devanado C1':[temp_dev1C],'Temperatura devanado C2':[temp_dev2C],
                                 'Temperatura descanso A':[temp_descA],'Temperatura descanso B':[temp_descB],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP27 = datos_PI_9300PP27.append(datos_actual_9300PP27,ignore_index=True)
    
    ######
    time_stamp = json.loads(valores[3].text)['Items'][0]['Value']['Timestamp']
    pres_salida = json.loads(valores[3].text)['Items'][0]['Value']['Value']
    flow = json.loads(valores[3].text)['Items'][1]['Value']['Value']
    vib_motor_b = json.loads(valores[3].text)['Items'][2]['Value']['Value']
    vib_motor_a = json.loads(valores[3].text)['Items'][3]['Value']['Value']
    vib_bomba_b = json.loads(valores[3].text)['Items'][4]['Value']['Value']
    vib_bomba_a = json.loads(valores[3].text)['Items'][5]['Value']['Value']
    temp_b = json.loads(valores[3].text)['Items'][6]['Value']['Value']
    temp_a = json.loads(valores[3].text)['Items'][7]['Value']['Value']
    temp_dev2C = json.loads(valores[3].text)['Items'][8]['Value']['Value']
    temp_dev2B = json.loads(valores[3].text)['Items'][9]['Value']['Value']
    temp_dev2A = json.loads(valores[3].text)['Items'][10]['Value']['Value']
    temp_dev1C = json.loads(valores[3].text)['Items'][11]['Value']['Value']
    temp_dev1B = json.loads(valores[3].text)['Items'][12]['Value']['Value']
    temp_dev1A = json.loads(valores[3].text)['Items'][13]['Value']['Value']
    temp_descB = json.loads(valores[3].text)['Items'][14]['Value']['Value']
    temp_descA = json.loads(valores[3].text)['Items'][15]['Value']['Value']
    pot_act = json.loads(valores[3].text)['Items'][16]['Value']['Value']
    hor_total = json.loads(valores[3].text)['Items'][17]['Value']['Value']
    hor_op = json.loads(valores[3].text)['Items'][18]['Value']['Value']
    ef = json.loads(valores[3].text)['Items'][19]['Value']['Value']
    corr_C = json.loads(valores[3].text)['Items'][20]['Value']['Value']
    corr_B = json.loads(valores[3].text)['Items'][21]['Value']['Value']
    corr_A = json.loads(valores[3].text)['Items'][22]['Value']['Value']

    datos_actual_9300PP28 = pd.DataFrame({'TimeStamp':[time_stamp],'Horometro total':[hor_total],'Horas operando':[hor_op],
                                 'Presion Salida':[pres_salida],'Flujo':[flow],'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],'Temperatura A':[temp_a],'Temperatura B':[temp_b],                               
                                 'Temperatura devanado A1':[temp_dev1A],'Temperatura devanado A2':[temp_dev2A],
                                 'Temperatura devanado B1':[temp_dev1B],'Temperatura devanado B2':[temp_dev2C],
                                 'Temperatura devanado C1':[temp_dev1C],'Temperatura devanado C2':[temp_dev2C],
                                 'Temperatura descanso A':[temp_descA],'Temperatura descanso B':[temp_descB],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP28 = datos_PI_9300PP28.append(datos_actual_9300PP28,ignore_index=True)
    
    ######
    time_stamp = json.loads(valores[4].text)['Items'][0]['Value']['Timestamp']
    pres_salida = json.loads(valores[4].text)['Items'][0]['Value']['Value']
    flow = json.loads(valores[4].text)['Items'][1]['Value']['Value']
    vib_motor_b = json.loads(valores[4].text)['Items'][2]['Value']['Value']
    vib_motor_a = json.loads(valores[4].text)['Items'][3]['Value']['Value']
    vib_bomba_b = json.loads(valores[4].text)['Items'][4]['Value']['Value']
    vib_bomba_a = json.loads(valores[4].text)['Items'][5]['Value']['Value']
    temp_b = json.loads(valores[4].text)['Items'][6]['Value']['Value']
    temp_a = json.loads(valores[4].text)['Items'][7]['Value']['Value']
    temp_dev2C = json.loads(valores[4].text)['Items'][8]['Value']['Value']
    temp_dev2B = json.loads(valores[4].text)['Items'][9]['Value']['Value']
    temp_dev2A = json.loads(valores[4].text)['Items'][10]['Value']['Value']
    temp_dev1C = json.loads(valores[4].text)['Items'][11]['Value']['Value']
    temp_dev1B = json.loads(valores[4].text)['Items'][12]['Value']['Value']
    temp_dev1A = json.loads(valores[4].text)['Items'][13]['Value']['Value']
    temp_descB = json.loads(valores[4].text)['Items'][14]['Value']['Value']
    temp_descA = json.loads(valores[4].text)['Items'][15]['Value']['Value']
    pot_act = json.loads(valores[4].text)['Items'][16]['Value']['Value']
    hor_total = json.loads(valores[4].text)['Items'][17]['Value']['Value']
    hor_op = json.loads(valores[4].text)['Items'][18]['Value']['Value']
    ef = json.loads(valores[4].text)['Items'][19]['Value']['Value']
    corr_C = json.loads(valores[4].text)['Items'][20]['Value']['Value']
    corr_B = json.loads(valores[4].text)['Items'][21]['Value']['Value']
    corr_A = json.loads(valores[4].text)['Items'][22]['Value']['Value']

    datos_actual_9300PP29 = pd.DataFrame({'TimeStamp':[time_stamp],'Horometro total':[hor_total],'Horas operando':[hor_op],
                                 'Presion Salida':[pres_salida],'Flujo':[flow],'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],'Temperatura A':[temp_a],'Temperatura B':[temp_b],                               
                                 'Temperatura devanado A1':[temp_dev1A],'Temperatura devanado A2':[temp_dev2A],
                                 'Temperatura devanado B1':[temp_dev1B],'Temperatura devanado B2':[temp_dev2C],
                                 'Temperatura devanado C1':[temp_dev1C],'Temperatura devanado C2':[temp_dev2C],
                                 'Temperatura descanso A':[temp_descA],'Temperatura descanso B':[temp_descB],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP29 = datos_PI_9300PP29.append(datos_actual_9300PP29,ignore_index=True)
    
    nombre_archivo = '9300_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
    with pd.ExcelWriter('~/jupyter/Datos_Bombas/EB2/'+nombre_archivo) as writer:  
        datos_PI_9300PP25.to_excel(writer,sheet_name='PP-025')
        datos_PI_9300PP26.to_excel(writer,sheet_name='PP-026')
        datos_PI_9300PP27.to_excel(writer,sheet_name='PP-027')
        datos_PI_9300PP28.to_excel(writer,sheet_name='PP-028')
        datos_PI_9300PP29.to_excel(writer,sheet_name='PP-029')
    
    ##### EB3 #####
    reqs = [grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwHLb2hC-h6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjNcOTMwMC1QUC0wMzE/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwdKeJkC-h6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjNcOTMwMC1QUC0wMzI/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwEZcNmS-h6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjNcOTMwMC1QUC0wMzM/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwFJcNmS-h6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjNcOTMwMC1QUC0wMzQ/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwbNxYpy-h6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjNcOTMwMC1QUC0wMzU/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),]
    
    valores = grequests.map(reqs)

    time_stamp = json.loads(valores[0].text)['Items'][0]['Value']['Timestamp']
    vib_motor_b = json.loads(valores[0].text)['Items'][0]['Value']['Value']
    vib_motor_a = json.loads(valores[0].text)['Items'][1]['Value']['Value']
    vib_bomba_b = json.loads(valores[0].text)['Items'][2]['Value']['Value']
    vib_bomba_a = json.loads(valores[0].text)['Items'][3]['Value']['Value']
    temp_b = json.loads(valores[0].text)['Items'][4]['Value']['Value']
    temp_a = json.loads(valores[0].text)['Items'][5]['Value']['Value']
    temp_dev = json.loads(valores[0].text)['Items'][6]['Value']['Value']
    temp_desc_tras = json.loads(valores[0].text)['Items'][7]['Value']['Value']
    temp_desc_del = json.loads(valores[0].text)['Items'][8]['Value']['Value']
    pump_running = json.loads(valores[0].text)['Items'][9]['Value']['Value']
    pot_act = json.loads(valores[0].text)['Items'][10]['Value']['Value']
    hor_op = json.loads(valores[0].text)['Items'][11]['Value']['Value']
    ef = json.loads(valores[0].text)['Items'][12]['Value']['Value']
    corr = json.loads(valores[0].text)['Items'][13]['Value']['Value']
    velocidad = json.loads(valores[0].text)['Items'][14]['Value']['Value']

    datos_actual_9300PP31 = pd.DataFrame({'TimeStamp':[time_stamp],'Horas operando':[hor_op],'Pump Runnig':[pump_running],
                                 'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],
                                 'Temperatura A':[temp_a],'Temperatura B':[temp_b],'Temperatura devanados':[temp_dev],
                                 'Temperatura descanso trasero':[temp_desc_tras],'Temperatura descanso delantero':[temp_desc_del],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente ':[corr],'Velocidad':[velocidad]})
    datos_PI_9300PP31 = datos_PI_9300PP31.append(datos_actual_9300PP31,ignore_index=True)
    
    ######
    time_stamp = json.loads(valores[1].text)['Items'][0]['Value']['Timestamp']
    vib_motor_b = json.loads(valores[1].text)['Items'][0]['Value']['Value']
    vib_motor_a = json.loads(valores[1].text)['Items'][1]['Value']['Value']
    vib_bomba_b = json.loads(valores[1].text)['Items'][2]['Value']['Value']
    vib_bomba_a = json.loads(valores[1].text)['Items'][3]['Value']['Value']
    temp_b = json.loads(valores[1].text)['Items'][4]['Value']['Value']
    temp_a = json.loads(valores[1].text)['Items'][5]['Value']['Value']
    temp_dev = json.loads(valores[1].text)['Items'][6]['Value']['Value']
    temp_desc_tras = json.loads(valores[1].text)['Items'][7]['Value']['Value']
    temp_desc_del = json.loads(valores[1].text)['Items'][8]['Value']['Value']
    pump_running = json.loads(valores[1].text)['Items'][9]['Value']['Value']
    pot_act = json.loads(valores[1].text)['Items'][10]['Value']['Value']
    hor_op = json.loads(valores[1].text)['Items'][11]['Value']['Value']
    ef = json.loads(valores[1].text)['Items'][12]['Value']['Value']
    corr = json.loads(valores[1].text)['Items'][13]['Value']['Value']
    velocidad = json.loads(valores[1].text)['Items'][14]['Value']['Value']

    datos_actual_9300PP32 = pd.DataFrame({'TimeStamp':[time_stamp],'Horas operando':[hor_op],'Pump Runnig':[pump_running],
                                 'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],
                                 'Temperatura A':[temp_a],'Temperatura B':[temp_b],'Temperatura devanados':[temp_dev],
                                 'Temperatura descanso trasero':[temp_desc_tras],'Temperatura descanso delantero':[temp_desc_del],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente ':[corr],'Velocidad':[velocidad]})
    datos_PI_9300PP32 = datos_PI_9300PP32.append(datos_actual_9300PP32,ignore_index=True)
    
    ######
    time_stamp = json.loads(valores[2].text)['Items'][0]['Value']['Timestamp']
    vib_motor_b = json.loads(valores[2].text)['Items'][0]['Value']['Value']
    vib_motor_a = json.loads(valores[2].text)['Items'][1]['Value']['Value']
    vib_bomba_b = json.loads(valores[2].text)['Items'][2]['Value']['Value']
    vib_bomba_a = json.loads(valores[2].text)['Items'][3]['Value']['Value']
    temp_b = json.loads(valores[2].text)['Items'][4]['Value']['Value']
    temp_a = json.loads(valores[2].text)['Items'][5]['Value']['Value']
    temp_dev = json.loads(valores[2].text)['Items'][6]['Value']['Value']
    temp_desc_tras = json.loads(valores[2].text)['Items'][7]['Value']['Value']
    temp_desc_del = json.loads(valores[2].text)['Items'][8]['Value']['Value']
    pump_running = json.loads(valores[2].text)['Items'][9]['Value']['Value']
    pot_act = json.loads(valores[2].text)['Items'][10]['Value']['Value']
    hor_op = json.loads(valores[2].text)['Items'][11]['Value']['Value']
    ef = json.loads(valores[2].text)['Items'][12]['Value']['Value']
    corr = json.loads(valores[2].text)['Items'][13]['Value']['Value']
    velocidad = json.loads(valores[2].text)['Items'][14]['Value']['Value']

    datos_actual_9300PP33 = pd.DataFrame({'TimeStamp':[time_stamp],'Horas operando':[hor_op],'Pump Runnig':[pump_running],
                                 'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],
                                 'Temperatura A':[temp_a],'Temperatura B':[temp_b],'Temperatura devanados':[temp_dev],
                                 'Temperatura descanso trasero':[temp_desc_tras],'Temperatura descanso delantero':[temp_desc_del],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente ':[corr],'Velocidad':[velocidad]})
    datos_PI_9300PP33 = datos_PI_9300PP33.append(datos_actual_9300PP33,ignore_index=True)
    
    ######
    time_stamp = json.loads(valores[3].text)['Items'][0]['Value']['Timestamp']
    vib_motor_b = json.loads(valores[3].text)['Items'][0]['Value']['Value']
    vib_motor_a = json.loads(valores[3].text)['Items'][1]['Value']['Value']
    vib_bomba_b = json.loads(valores[3].text)['Items'][2]['Value']['Value']
    vib_bomba_a = json.loads(valores[3].text)['Items'][3]['Value']['Value']
    temp_b = json.loads(valores[3].text)['Items'][4]['Value']['Value']
    temp_a = json.loads(valores[3].text)['Items'][5]['Value']['Value']
    temp_dev = json.loads(valores[3].text)['Items'][6]['Value']['Value']
    temp_desc_tras = json.loads(valores[3].text)['Items'][7]['Value']['Value']
    temp_desc_del = json.loads(valores[3].text)['Items'][8]['Value']['Value']
    pump_running = json.loads(valores[3].text)['Items'][9]['Value']['Value']
    pot_act = json.loads(valores[3].text)['Items'][10]['Value']['Value']
    hor_op = json.loads(valores[3].text)['Items'][11]['Value']['Value']
    ef = json.loads(valores[3].text)['Items'][12]['Value']['Value']
    corr = json.loads(valores[3].text)['Items'][13]['Value']['Value']
    velocidad = json.loads(valores[3].text)['Items'][14]['Value']['Value']

    datos_actual_9300PP34 = pd.DataFrame({'TimeStamp':[time_stamp],'Horas operando':[hor_op],'Pump Runnig':[pump_running],
                                 'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],
                                 'Temperatura A':[temp_a],'Temperatura B':[temp_b],'Temperatura devanados':[temp_dev],
                                 'Temperatura descanso trasero':[temp_desc_tras],'Temperatura descanso delantero':[temp_desc_del],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente ':[corr],'Velocidad':[velocidad]})
    datos_PI_9300PP34 = datos_PI_9300PP34.append(datos_actual_9300PP34,ignore_index=True)
    
    ######
    time_stamp = json.loads(valores[4].text)['Items'][0]['Value']['Timestamp']
    vib_motor_b = json.loads(valores[4].text)['Items'][0]['Value']['Value']
    vib_motor_a = json.loads(valores[4].text)['Items'][1]['Value']['Value']
    vib_bomba_b = json.loads(valores[4].text)['Items'][2]['Value']['Value']
    vib_bomba_a = json.loads(valores[4].text)['Items'][3]['Value']['Value']
    temp_b = json.loads(valores[4].text)['Items'][4]['Value']['Value']
    temp_a = json.loads(valores[4].text)['Items'][5]['Value']['Value']
    temp_dev = json.loads(valores[4].text)['Items'][6]['Value']['Value']
    temp_desc_tras = json.loads(valores[4].text)['Items'][7]['Value']['Value']
    temp_desc_del = json.loads(valores[4].text)['Items'][8]['Value']['Value']
    pump_running = json.loads(valores[4].text)['Items'][9]['Value']['Value']
    pot_act = json.loads(valores[4].text)['Items'][10]['Value']['Value']
    hor_op = json.loads(valores[4].text)['Items'][11]['Value']['Value']
    ef = json.loads(valores[4].text)['Items'][12]['Value']['Value']
    corr = json.loads(valores[4].text)['Items'][13]['Value']['Value']
    velocidad = json.loads(valores[4].text)['Items'][14]['Value']['Value']

    datos_actual_9300PP35 = pd.DataFrame({'TimeStamp':[time_stamp],'Horas operando':[hor_op],'Pump Runnig':[pump_running],
                                 'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],
                                 'Temperatura A':[temp_a],'Temperatura B':[temp_b],'Temperatura devanados':[temp_dev],
                                 'Temperatura descanso trasero':[temp_desc_tras],'Temperatura descanso delantero':[temp_desc_del],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente ':[corr],'Velocidad':[velocidad]})
    datos_PI_9300PP35 = datos_PI_9300PP35.append(datos_actual_9300PP35,ignore_index=True)
    
    nombre_archivo = '9300_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
    with pd.ExcelWriter('~/jupyter/Datos_Bombas/EB3/'+nombre_archivo) as writer:  
        datos_PI_9300PP31.to_excel(writer,sheet_name='PP-031')
        datos_PI_9300PP32.to_excel(writer,sheet_name='PP-032')
        datos_PI_9300PP33.to_excel(writer,sheet_name='PP-033')
        datos_PI_9300PP34.to_excel(writer,sheet_name='PP-034')
        datos_PI_9300PP35.to_excel(writer,sheet_name='PP-035')

    ##### EB5 #####
    reqs = [grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwBp17fDGh6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjVcOTMwMC1QUC0wNjU/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCw9p1ohTGh6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjVcOTMwMC1QUC0wNjY/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCw9ihmkzGh6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjVcOTMwMC1QUC0wNjc/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCw9qAWnTGh6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjVcOTMwMC1QUC0wNjg/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCw-aAWnTGh6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjVcOTMwMC1QUC0wNjk/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),]
    
    valores = grequests.map(reqs)

    time_stamp = json.loads(valores[0].text)['Items'][0]['Value']['Timestamp']
    TI91660B = json.loads(valores[0].text)['Items'][0]['Value']['Value']
    TI91660A = json.loads(valores[0].text)['Items'][1]['Value']['Value']
    vib_motor_b = json.loads(valores[0].text)['Items'][2]['Value']['Value']
    vib_motor_a = json.loads(valores[0].text)['Items'][3]['Value']['Value']
    vib_bomba_b = json.loads(valores[0].text)['Items'][4]['Value']['Value']
    vib_bomba_a = json.loads(valores[0].text)['Items'][5]['Value']['Value']
    temp_dev2C = json.loads(valores[0].text)['Items'][6]['Value']['Value']
    temp_dev2B = json.loads(valores[0].text)['Items'][7]['Value']['Value']
    temp_dev2A = json.loads(valores[0].text)['Items'][8]['Value']['Value']
    temp_dev1C = json.loads(valores[0].text)['Items'][9]['Value']['Value']
    temp_dev1B = json.loads(valores[0].text)['Items'][10]['Value']['Value']
    temp_dev1A = json.loads(valores[0].text)['Items'][11]['Value']['Value']
    temp_descB = json.loads(valores[0].text)['Items'][12]['Value']['Value']
    temp_descA = json.loads(valores[0].text)['Items'][13]['Value']['Value']
    pot_act = json.loads(valores[0].text)['Items'][14]['Value']['Value']
    hor_total = json.loads(valores[0].text)['Items'][15]['Value']['Value']
    hor_op = json.loads(valores[0].text)['Items'][16]['Value']['Value']
    ef = json.loads(valores[0].text)['Items'][17]['Value']['Value']
    corr_C = json.loads(valores[0].text)['Items'][18]['Value']['Value']
    corr_B = json.loads(valores[0].text)['Items'][19]['Value']['Value']
    corr_A = json.loads(valores[0].text)['Items'][20]['Value']['Value']

    datos_actual_9300PP65 = pd.DataFrame({'TimeStamp':[time_stamp],'Horometro total':[hor_total],'Horas operando':[hor_op],
                                 'TI91660B':[TI91660B],'TI91660A':[TI91660A],'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],
                                 'Temperatura devanado A1':[temp_dev1A],'Temperatura devanado A2':[temp_dev2A],
                                 'Temperatura devanado B1':[temp_dev1B],'Temperatura devanado B2':[temp_dev2C],
                                 'Temperatura devanado C1':[temp_dev1C],'Temperatura devanado C2':[temp_dev2C],
                                 'Temperatura descanso A':[temp_descA],'Temperatura descanso B':[temp_descB],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP65 = datos_PI_9300PP65.append(datos_actual_9300PP65,ignore_index=True)
    
    #####
    time_stamp = json.loads(valores[1].text)['Items'][0]['Value']['Timestamp']
    TI91660B = json.loads(valores[1].text)['Items'][0]['Value']['Value']
    TI91660A = json.loads(valores[1].text)['Items'][1]['Value']['Value']
    vib_motor_b = json.loads(valores[1].text)['Items'][2]['Value']['Value']
    vib_motor_a = json.loads(valores[1].text)['Items'][3]['Value']['Value']
    vib_bomba_b = json.loads(valores[1].text)['Items'][4]['Value']['Value']
    vib_bomba_a = json.loads(valores[1].text)['Items'][5]['Value']['Value']
    temp_dev2C = json.loads(valores[1].text)['Items'][6]['Value']['Value']
    temp_dev2B = json.loads(valores[1].text)['Items'][7]['Value']['Value']
    temp_dev2A = json.loads(valores[1].text)['Items'][8]['Value']['Value']
    temp_dev1C = json.loads(valores[1].text)['Items'][9]['Value']['Value']
    temp_dev1B = json.loads(valores[1].text)['Items'][10]['Value']['Value']
    temp_dev1A = json.loads(valores[1].text)['Items'][11]['Value']['Value']
    temp_descB = json.loads(valores[1].text)['Items'][12]['Value']['Value']
    temp_descA = json.loads(valores[1].text)['Items'][13]['Value']['Value']
    pot_act = json.loads(valores[1].text)['Items'][14]['Value']['Value']
    hor_total = json.loads(valores[1].text)['Items'][15]['Value']['Value']
    hor_op = json.loads(valores[1].text)['Items'][16]['Value']['Value']
    ef = json.loads(valores[1].text)['Items'][17]['Value']['Value']
    corr_C = json.loads(valores[1].text)['Items'][18]['Value']['Value']
    corr_B = json.loads(valores[1].text)['Items'][19]['Value']['Value']
    corr_A = json.loads(valores[1].text)['Items'][20]['Value']['Value']

    datos_actual_9300PP66 = pd.DataFrame({'TimeStamp':[time_stamp],'Horometro total':[hor_total],'Horas operando':[hor_op],
                                 'TI91660B':[TI91660B],'TI91660A':[TI91660A],'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],
                                 'Temperatura devanado A1':[temp_dev1A],'Temperatura devanado A2':[temp_dev2A],
                                 'Temperatura devanado B1':[temp_dev1B],'Temperatura devanado B2':[temp_dev2C],
                                 'Temperatura devanado C1':[temp_dev1C],'Temperatura devanado C2':[temp_dev2C],
                                 'Temperatura descanso A':[temp_descA],'Temperatura descanso B':[temp_descB],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP66 = datos_PI_9300PP65.append(datos_actual_9300PP66,ignore_index=True)
    
    #####
    time_stamp = json.loads(valores[2].text)['Items'][0]['Value']['Timestamp']
    TI91660B = json.loads(valores[2].text)['Items'][0]['Value']['Value']
    TI91660A = json.loads(valores[2].text)['Items'][1]['Value']['Value']
    vib_motor_b = json.loads(valores[2].text)['Items'][2]['Value']['Value']
    vib_motor_a = json.loads(valores[2].text)['Items'][3]['Value']['Value']
    vib_bomba_b = json.loads(valores[2].text)['Items'][4]['Value']['Value']
    vib_bomba_a = json.loads(valores[2].text)['Items'][5]['Value']['Value']
    temp_dev2C = json.loads(valores[2].text)['Items'][6]['Value']['Value']
    temp_dev2B = json.loads(valores[2].text)['Items'][7]['Value']['Value']
    temp_dev2A = json.loads(valores[2].text)['Items'][8]['Value']['Value']
    temp_dev1C = json.loads(valores[2].text)['Items'][9]['Value']['Value']
    temp_dev1B = json.loads(valores[2].text)['Items'][10]['Value']['Value']
    temp_dev1A = json.loads(valores[2].text)['Items'][11]['Value']['Value']
    temp_descB = json.loads(valores[2].text)['Items'][12]['Value']['Value']
    temp_descA = json.loads(valores[2].text)['Items'][13]['Value']['Value']
    pot_act = json.loads(valores[2].text)['Items'][14]['Value']['Value']
    hor_total = json.loads(valores[2].text)['Items'][15]['Value']['Value']
    hor_op = json.loads(valores[2].text)['Items'][16]['Value']['Value']
    ef = json.loads(valores[2].text)['Items'][17]['Value']['Value']
    corr_C = json.loads(valores[2].text)['Items'][18]['Value']['Value']
    corr_B = json.loads(valores[2].text)['Items'][19]['Value']['Value']
    corr_A = json.loads(valores[2].text)['Items'][20]['Value']['Value']

    datos_actual_9300PP67 = pd.DataFrame({'TimeStamp':[time_stamp],'Horometro total':[hor_total],'Horas operando':[hor_op],
                                 'TI91660B':[TI91660B],'TI91660A':[TI91660A],'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],
                                 'Temperatura devanado A1':[temp_dev1A],'Temperatura devanado A2':[temp_dev2A],
                                 'Temperatura devanado B1':[temp_dev1B],'Temperatura devanado B2':[temp_dev2C],
                                 'Temperatura devanado C1':[temp_dev1C],'Temperatura devanado C2':[temp_dev2C],
                                 'Temperatura descanso A':[temp_descA],'Temperatura descanso B':[temp_descB],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP67 = datos_PI_9300PP67.append(datos_actual_9300PP67,ignore_index=True)
    
    #####
    time_stamp = json.loads(valores[3].text)['Items'][0]['Value']['Timestamp']
    TI91660B = json.loads(valores[3].text)['Items'][0]['Value']['Value']
    TI91660A = json.loads(valores[3].text)['Items'][1]['Value']['Value']
    vib_motor_b = json.loads(valores[3].text)['Items'][2]['Value']['Value']
    vib_motor_a = json.loads(valores[3].text)['Items'][3]['Value']['Value']
    vib_bomba_b = json.loads(valores[3].text)['Items'][4]['Value']['Value']
    vib_bomba_a = json.loads(valores[3].text)['Items'][5]['Value']['Value']
    temp_dev2C = json.loads(valores[3].text)['Items'][6]['Value']['Value']
    temp_dev2B = json.loads(valores[3].text)['Items'][7]['Value']['Value']
    temp_dev2A = json.loads(valores[3].text)['Items'][8]['Value']['Value']
    temp_dev1C = json.loads(valores[3].text)['Items'][9]['Value']['Value']
    temp_dev1B = json.loads(valores[3].text)['Items'][10]['Value']['Value']
    temp_dev1A = json.loads(valores[3].text)['Items'][11]['Value']['Value']
    temp_descB = json.loads(valores[3].text)['Items'][12]['Value']['Value']
    temp_descA = json.loads(valores[3].text)['Items'][13]['Value']['Value']
    pot_act = json.loads(valores[3].text)['Items'][14]['Value']['Value']
    hor_total = json.loads(valores[3].text)['Items'][15]['Value']['Value']
    hor_op = json.loads(valores[3].text)['Items'][16]['Value']['Value']
    ef = json.loads(valores[3].text)['Items'][17]['Value']['Value']
    corr_C = json.loads(valores[3].text)['Items'][18]['Value']['Value']
    corr_B = json.loads(valores[3].text)['Items'][19]['Value']['Value']
    corr_A = json.loads(valores[3].text)['Items'][20]['Value']['Value']

    datos_actual_9300PP68 = pd.DataFrame({'TimeStamp':[time_stamp],'Horometro total':[hor_total],'Horas operando':[hor_op],
                                 'TI91660B':[TI91660B],'TI91660A':[TI91660A],'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],
                                 'Temperatura devanado A1':[temp_dev1A],'Temperatura devanado A2':[temp_dev2A],
                                 'Temperatura devanado B1':[temp_dev1B],'Temperatura devanado B2':[temp_dev2C],
                                 'Temperatura devanado C1':[temp_dev1C],'Temperatura devanado C2':[temp_dev2C],
                                 'Temperatura descanso A':[temp_descA],'Temperatura descanso B':[temp_descB],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP68 = datos_PI_9300PP68.append(datos_actual_9300PP68,ignore_index=True)
    
    time_stamp = json.loads(valores[4].text)['Items'][0]['Value']['Timestamp']
    TI91660B = json.loads(valores[4].text)['Items'][0]['Value']['Value']
    TI91660A = json.loads(valores[4].text)['Items'][1]['Value']['Value']
    vib_motor_b = json.loads(valores[4].text)['Items'][2]['Value']['Value']
    vib_motor_a = json.loads(valores[4].text)['Items'][3]['Value']['Value']
    vib_bomba_b = json.loads(valores[4].text)['Items'][4]['Value']['Value']
    vib_bomba_a = json.loads(valores[4].text)['Items'][5]['Value']['Value']
    temp_dev2C = json.loads(valores[4].text)['Items'][6]['Value']['Value']
    temp_dev2B = json.loads(valores[4].text)['Items'][7]['Value']['Value']
    temp_dev2A = json.loads(valores[4].text)['Items'][8]['Value']['Value']
    temp_dev1C = json.loads(valores[4].text)['Items'][9]['Value']['Value']
    temp_dev1B = json.loads(valores[4].text)['Items'][10]['Value']['Value']
    temp_dev1A = json.loads(valores[4].text)['Items'][11]['Value']['Value']
    temp_descB = json.loads(valores[4].text)['Items'][12]['Value']['Value']
    temp_descA = json.loads(valores[4].text)['Items'][13]['Value']['Value']
    pot_act = json.loads(valores[4].text)['Items'][14]['Value']['Value']
    hor_total = json.loads(valores[4].text)['Items'][15]['Value']['Value']
    hor_op = json.loads(valores[4].text)['Items'][16]['Value']['Value']
    ef = json.loads(valores[4].text)['Items'][17]['Value']['Value']
    corr_C = json.loads(valores[4].text)['Items'][18]['Value']['Value']
    corr_B = json.loads(valores[4].text)['Items'][19]['Value']['Value']
    corr_A = json.loads(valores[4].text)['Items'][20]['Value']['Value']

    datos_actual_9300PP69 = pd.DataFrame({'TimeStamp':[time_stamp],'Horometro total':[hor_total],'Horas operando':[hor_op],
                                 'TI91660B':[TI91660B],'TI91660A':[TI91660A],'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],
                                 'Temperatura devanado A1':[temp_dev1A],'Temperatura devanado A2':[temp_dev2A],
                                 'Temperatura devanado B1':[temp_dev1B],'Temperatura devanado B2':[temp_dev2C],
                                 'Temperatura devanado C1':[temp_dev1C],'Temperatura devanado C2':[temp_dev2C],
                                 'Temperatura descanso A':[temp_descA],'Temperatura descanso B':[temp_descB],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP69 = datos_PI_9300PP69.append(datos_actual_9300PP69,ignore_index=True)
    
    nombre_archivo = '9300_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
    with pd.ExcelWriter('~/jupyter/Datos_Bombas/EB5/'+nombre_archivo) as writer:  
        datos_PI_9300PP65.to_excel(writer,sheet_name='PP-065')
        datos_PI_9300PP66.to_excel(writer,sheet_name='PP-066')
        datos_PI_9300PP67.to_excel(writer,sheet_name='PP-067')
        datos_PI_9300PP68.to_excel(writer,sheet_name='PP-068')
        datos_PI_9300PP69.to_excel(writer,sheet_name='PP-069')
    
    
    ##### EB6 #####
    reqs = [grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwkj_k4DOh6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjZcOTMwMC1QUC0wNzE/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwlT_k4DOh6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjZcOTMwMC1QUC0wNzI/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwvtb-7jOh6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjZcOTMwMC1QUC0wNzM/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwcE5o9jOh6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjZcOTMwMC1QUC0wNzQ/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),
        grequests.get('https://piwebapi.caserones.cl:8443/piwebapi/streamsets/F1EmiGOb_efVU0GUF6kOZIrFCwc05o9jOh6xGCEwBQVpZaMgTUxDQ1BJQUYwMVxQSVdFQlNFUlZJQ0VTXEJPTUJBU1xFQjZcOTMwMC1QUC0wNzU/value',auth=HTTPBasicAuth('vulco.esed','vpump$mlcc2021')),]
    
    valores = grequests.map(reqs)

    time_stamp = json.loads(valores[0].text)['Items'][0]['Value']['Timestamp']
    vib_motor_b = json.loads(valores[0].text)['Items'][0]['Value']['Value']
    vib_motor_a = json.loads(valores[0].text)['Items'][1]['Value']['Value']
    vib_bomba_b = json.loads(valores[0].text)['Items'][2]['Value']['Value']
    vib_bomba_a = json.loads(valores[0].text)['Items'][3]['Value']['Value']
    TI91720B = json.loads(valores[0].text)['Items'][4]['Value']['Value']
    TI91720A = json.loads(valores[0].text)['Items'][5]['Value']['Value']
    temp_dev2C = json.loads(valores[0].text)['Items'][6]['Value']['Value']
    temp_dev2B = json.loads(valores[0].text)['Items'][7]['Value']['Value']
    temp_dev2A = json.loads(valores[0].text)['Items'][8]['Value']['Value']
    temp_dev1C = json.loads(valores[0].text)['Items'][9]['Value']['Value']
    temp_dev1B = json.loads(valores[0].text)['Items'][10]['Value']['Value']
    temp_dev1A = json.loads(valores[0].text)['Items'][11]['Value']['Value']
    temp_descB = json.loads(valores[0].text)['Items'][12]['Value']['Value']
    temp_descA = json.loads(valores[0].text)['Items'][13]['Value']['Value']
    pump_running = json.loads(valores[0].text)['Items'][14]['Value']['Value']
    pot_act = json.loads(valores[0].text)['Items'][15]['Value']['Value']
    hor_total = json.loads(valores[0].text)['Items'][16]['Value']['Value']
    hor_op = json.loads(valores[0].text)['Items'][17]['Value']['Value']
    ef = json.loads(valores[0].text)['Items'][18]['Value']['Value']
    corr_C = json.loads(valores[0].text)['Items'][19]['Value']['Value']
    corr_B = json.loads(valores[0].text)['Items'][20]['Value']['Value']
    corr_A = json.loads(valores[0].text)['Items'][21]['Value']['Value']

    datos_actual_9300PP71 = pd.DataFrame({'TimeStamp':[time_stamp],'Horometro total':[hor_total],'Horas operando':[hor_op],'Pump Running':[pump_running],
                                 'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],
                                 'TI91720B':[TI91720B],'TI91720A':[TI91720A],
                                 'Temperatura devanado A1':[temp_dev1A],'Temperatura devanado A2':[temp_dev2A],
                                 'Temperatura devanado B1':[temp_dev1B],'Temperatura devanado B2':[temp_dev2C],
                                 'Temperatura devanado C1':[temp_dev1C],'Temperatura devanado C2':[temp_dev2C],
                                 'Temperatura descanso A':[temp_descA],'Temperatura descanso B':[temp_descB],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP71 = datos_PI_9300PP71.append(datos_actual_9300PP71,ignore_index=True)
    
    #####
    time_stamp = json.loads(valores[1].text)['Items'][0]['Value']['Timestamp']
    vib_motor_b = json.loads(valores[1].text)['Items'][0]['Value']['Value']
    vib_motor_a = json.loads(valores[1].text)['Items'][1]['Value']['Value']
    vib_bomba_b = json.loads(valores[1].text)['Items'][2]['Value']['Value']
    vib_bomba_a = json.loads(valores[1].text)['Items'][3]['Value']['Value']
    TI91720B = json.loads(valores[1].text)['Items'][4]['Value']['Value']
    TI91720A = json.loads(valores[1].text)['Items'][5]['Value']['Value']
    temp_dev2C = json.loads(valores[1].text)['Items'][6]['Value']['Value']
    temp_dev2B = json.loads(valores[1].text)['Items'][7]['Value']['Value']
    temp_dev2A = json.loads(valores[1].text)['Items'][8]['Value']['Value']
    temp_dev1C = json.loads(valores[1].text)['Items'][9]['Value']['Value']
    temp_dev1B = json.loads(valores[1].text)['Items'][10]['Value']['Value']
    temp_dev1A = json.loads(valores[1].text)['Items'][11]['Value']['Value']
    temp_descB = json.loads(valores[1].text)['Items'][12]['Value']['Value']
    temp_descA = json.loads(valores[1].text)['Items'][13]['Value']['Value']
    pump_running = json.loads(valores[1].text)['Items'][14]['Value']['Value']
    pot_act = json.loads(valores[1].text)['Items'][15]['Value']['Value']
    hor_total = json.loads(valores[1].text)['Items'][16]['Value']['Value']
    hor_op = json.loads(valores[1].text)['Items'][17]['Value']['Value']
    ef = json.loads(valores[1].text)['Items'][18]['Value']['Value']
    corr_C = json.loads(valores[1].text)['Items'][19]['Value']['Value']
    corr_B = json.loads(valores[1].text)['Items'][20]['Value']['Value']
    corr_A = json.loads(valores[1].text)['Items'][21]['Value']['Value']

    datos_actual_9300PP72 = pd.DataFrame({'TimeStamp':[time_stamp],'Horometro total':[hor_total],'Horas operando':[hor_op],'Pump Running':[pump_running],
                                 'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],
                                 'TI91720B':[TI91720B],'TI91720A':[TI91720A],
                                 'Temperatura devanado A1':[temp_dev1A],'Temperatura devanado A2':[temp_dev2A],
                                 'Temperatura devanado B1':[temp_dev1B],'Temperatura devanado B2':[temp_dev2C],
                                 'Temperatura devanado C1':[temp_dev1C],'Temperatura devanado C2':[temp_dev2C],
                                 'Temperatura descanso A':[temp_descA],'Temperatura descanso B':[temp_descB],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP72 = datos_PI_9300PP72.append(datos_actual_9300PP72,ignore_index=True)
    
    #####
    time_stamp = json.loads(valores[2].text)['Items'][0]['Value']['Timestamp']
    vib_motor_b = json.loads(valores[2].text)['Items'][0]['Value']['Value']
    vib_motor_a = json.loads(valores[2].text)['Items'][1]['Value']['Value']
    vib_bomba_b = json.loads(valores[2].text)['Items'][2]['Value']['Value']
    vib_bomba_a = json.loads(valores[2].text)['Items'][3]['Value']['Value']
    TI91720B = json.loads(valores[2].text)['Items'][4]['Value']['Value']
    TI91720A = json.loads(valores[2].text)['Items'][5]['Value']['Value']
    temp_dev2C = json.loads(valores[2].text)['Items'][6]['Value']['Value']
    temp_dev2B = json.loads(valores[2].text)['Items'][7]['Value']['Value']
    temp_dev2A = json.loads(valores[2].text)['Items'][8]['Value']['Value']
    temp_dev1C = json.loads(valores[2].text)['Items'][9]['Value']['Value']
    temp_dev1B = json.loads(valores[2].text)['Items'][10]['Value']['Value']
    temp_dev1A = json.loads(valores[2].text)['Items'][11]['Value']['Value']
    temp_descB = json.loads(valores[2].text)['Items'][12]['Value']['Value']
    temp_descA = json.loads(valores[2].text)['Items'][13]['Value']['Value']
    pump_running = json.loads(valores[2].text)['Items'][14]['Value']['Value']
    pot_act = json.loads(valores[2].text)['Items'][15]['Value']['Value']
    hor_total = json.loads(valores[2].text)['Items'][16]['Value']['Value']
    hor_op = json.loads(valores[2].text)['Items'][17]['Value']['Value']
    ef = json.loads(valores[2].text)['Items'][18]['Value']['Value']
    corr_C = json.loads(valores[2].text)['Items'][19]['Value']['Value']
    corr_B = json.loads(valores[2].text)['Items'][20]['Value']['Value']
    corr_A = json.loads(valores[2].text)['Items'][21]['Value']['Value']

    datos_actual_9300PP73 = pd.DataFrame({'TimeStamp':[time_stamp],'Horometro total':[hor_total],'Horas operando':[hor_op],'Pump Running':[pump_running],
                                 'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],
                                 'TI91720B':[TI91720B],'TI91720A':[TI91720A],
                                 'Temperatura devanado A1':[temp_dev1A],'Temperatura devanado A2':[temp_dev2A],
                                 'Temperatura devanado B1':[temp_dev1B],'Temperatura devanado B2':[temp_dev2C],
                                 'Temperatura devanado C1':[temp_dev1C],'Temperatura devanado C2':[temp_dev2C],
                                 'Temperatura descanso A':[temp_descA],'Temperatura descanso B':[temp_descB],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP73 = datos_PI_9300PP73.append(datos_actual_9300PP73,ignore_index=True)
    
    #####
    time_stamp = json.loads(valores[3].text)['Items'][0]['Value']['Timestamp']
    vib_motor_b = json.loads(valores[3].text)['Items'][0]['Value']['Value']
    vib_motor_a = json.loads(valores[3].text)['Items'][1]['Value']['Value']
    vib_bomba_b = json.loads(valores[3].text)['Items'][2]['Value']['Value']
    vib_bomba_a = json.loads(valores[3].text)['Items'][3]['Value']['Value']
    TI91720B = json.loads(valores[3].text)['Items'][4]['Value']['Value']
    TI91720A = json.loads(valores[3].text)['Items'][5]['Value']['Value']
    temp_dev2C = json.loads(valores[3].text)['Items'][6]['Value']['Value']
    temp_dev2B = json.loads(valores[3].text)['Items'][7]['Value']['Value']
    temp_dev2A = json.loads(valores[3].text)['Items'][8]['Value']['Value']
    temp_dev1C = json.loads(valores[3].text)['Items'][9]['Value']['Value']
    temp_dev1B = json.loads(valores[3].text)['Items'][10]['Value']['Value']
    temp_dev1A = json.loads(valores[3].text)['Items'][11]['Value']['Value']
    temp_descB = json.loads(valores[3].text)['Items'][12]['Value']['Value']
    temp_descA = json.loads(valores[3].text)['Items'][13]['Value']['Value']
    pump_running = json.loads(valores[3].text)['Items'][14]['Value']['Value']
    pot_act = json.loads(valores[3].text)['Items'][15]['Value']['Value']
    hor_total = json.loads(valores[3].text)['Items'][16]['Value']['Value']
    hor_op = json.loads(valores[3].text)['Items'][17]['Value']['Value']
    ef = json.loads(valores[3].text)['Items'][18]['Value']['Value']
    corr_C = json.loads(valores[3].text)['Items'][19]['Value']['Value']
    corr_B = json.loads(valores[3].text)['Items'][20]['Value']['Value']
    corr_A = json.loads(valores[3].text)['Items'][21]['Value']['Value']

    datos_actual_9300PP74 = pd.DataFrame({'TimeStamp':[time_stamp],'Horometro total':[hor_total],'Horas operando':[hor_op],'Pump Running':[pump_running],
                                 'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],
                                 'TI91720B':[TI91720B],'TI91720A':[TI91720A],
                                 'Temperatura devanado A1':[temp_dev1A],'Temperatura devanado A2':[temp_dev2A],
                                 'Temperatura devanado B1':[temp_dev1B],'Temperatura devanado B2':[temp_dev2C],
                                 'Temperatura devanado C1':[temp_dev1C],'Temperatura devanado C2':[temp_dev2C],
                                 'Temperatura descanso A':[temp_descA],'Temperatura descanso B':[temp_descB],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP74 = datos_PI_9300PP74.append(datos_actual_9300PP74,ignore_index=True)
    
    #####
    time_stamp = json.loads(valores[4].text)['Items'][0]['Value']['Timestamp']
    vib_motor_b = json.loads(valores[4].text)['Items'][0]['Value']['Value']
    vib_motor_a = json.loads(valores[4].text)['Items'][1]['Value']['Value']
    vib_bomba_b = json.loads(valores[4].text)['Items'][2]['Value']['Value']
    vib_bomba_a = json.loads(valores[4].text)['Items'][3]['Value']['Value']
    TI91720B = json.loads(valores[4].text)['Items'][4]['Value']['Value']
    TI91720A = json.loads(valores[4].text)['Items'][5]['Value']['Value']
    temp_dev2C = json.loads(valores[4].text)['Items'][6]['Value']['Value']
    temp_dev2B = json.loads(valores[4].text)['Items'][7]['Value']['Value']
    temp_dev2A = json.loads(valores[4].text)['Items'][8]['Value']['Value']
    temp_dev1C = json.loads(valores[4].text)['Items'][9]['Value']['Value']
    temp_dev1B = json.loads(valores[4].text)['Items'][10]['Value']['Value']
    temp_dev1A = json.loads(valores[4].text)['Items'][11]['Value']['Value']
    temp_descB = json.loads(valores[4].text)['Items'][12]['Value']['Value']
    temp_descA = json.loads(valores[4].text)['Items'][13]['Value']['Value']
    pump_running = json.loads(valores[4].text)['Items'][14]['Value']['Value']
    pot_act = json.loads(valores[4].text)['Items'][15]['Value']['Value']
    hor_total = json.loads(valores[4].text)['Items'][16]['Value']['Value']
    hor_op = json.loads(valores[4].text)['Items'][17]['Value']['Value']
    ef = json.loads(valores[4].text)['Items'][18]['Value']['Value']
    corr_C = json.loads(valores[4].text)['Items'][19]['Value']['Value']
    corr_B = json.loads(valores[4].text)['Items'][20]['Value']['Value']
    corr_A = json.loads(valores[4].text)['Items'][21]['Value']['Value']

    datos_actual_9300PP75 = pd.DataFrame({'TimeStamp':[time_stamp],'Horometro total':[hor_total],'Horas operando':[hor_op],'Pump Running':[pump_running],
                                 'Vibracion Motor A':[vib_motor_a],'Vibracion Motor B':[vib_motor_b],
                                 'Vibracion Bomba A':[vib_bomba_a],'Vibracion Bomba B':[vib_bomba_b],
                                 'TI91720B':[TI91720B],'TI91720A':[TI91720A],
                                 'Temperatura devanado A1':[temp_dev1A],'Temperatura devanado A2':[temp_dev2A],
                                 'Temperatura devanado B1':[temp_dev1B],'Temperatura devanado B2':[temp_dev2C],
                                 'Temperatura devanado C1':[temp_dev1C],'Temperatura devanado C2':[temp_dev2C],
                                 'Temperatura descanso A':[temp_descA],'Temperatura descanso B':[temp_descB],
                                 'Potencia Activa':[pot_act],'Eficiencia':[ef],
                                 'Corriente A':[corr_A],'Corriente B':[corr_B],'Corriente C':[corr_C]})
    datos_PI_9300PP75 = datos_PI_9300PP75.append(datos_actual_9300PP75,ignore_index=True)

    nombre_archivo = '9300_{}-{}-{}.xlsx'.format(now.year,now.month,now.day)
    with pd.ExcelWriter('~/jupyter/Datos_Bombas/EB6/'+nombre_archivo) as writer:  
        datos_PI_9300PP71.to_excel(writer,sheet_name='PP-071')
        datos_PI_9300PP72.to_excel(writer,sheet_name='PP-072')
        datos_PI_9300PP73.to_excel(writer,sheet_name='PP-073')
        datos_PI_9300PP74.to_excel(writer,sheet_name='PP-074')
        datos_PI_9300PP75.to_excel(writer,sheet_name='PP-075')
    
    time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-6ae70d54dc24> in <module>
#       8     valores = grequests.map(reqs)
#       9
# ---> 10     time_stamp = json.loads(valores[0].text)['Items'][0]['Value']['Timestamp']
#      11     pres_est4 = json.loads(valores[0].text)['Items'][0]['Value']['Value']
#      12     flow = json.loads(valores[0].text)['Items'][1]['Value']['Value']
#
# AttributeError: 'NoneType' object has no attribute 'text'
